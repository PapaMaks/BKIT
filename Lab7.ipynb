# %% [markdown]
# <a href="https://colab.research.google.com/github/PapaMaks/BKIT/blob/master/Lab7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Лабораторная работа №7

# %% [markdown]
# # Задание

# %% [markdown]
# Выбрать свой корпус текста и обучить последовательно на нём три архитектуры нейронных сетей на
# задаче Next Token Prediction (предсказание следующего токена).
#
# Архитектуры:
# * Одномерная свёрточная нейронная сеть
# * Рекуррентная нейронная сеть
# * Трансформер кодировщик
#
# Визуализировать полученное векторное представление токенов. Сохранить модели в формате onnx.
#
# Дописать код для генерации текста по входной последовательности.
#
# В качестве примера приводится обучение на русском корпусе текста - произведении
# Ф.М. Достоевского "Преступление и наказание".

# %% [markdown]
# Отчет должен содержать: титульный лист, задание с вариантом корпуса текста, скриншоты и краткие пояснения по каждому этапу лабораторной работы, визуализация векторного представления.

# %% [markdown]
# #Контрольные вопросы
# 1. Предобработка текста
# 2. Архитектура трансформер
# 3. Удаление шумовых слов
# 4. Стемминг и лемматизация
# 5. Что такое эмбеддинг?

# %% [markdown]
# #Выполнение лабораторной работы

# %% [markdown]
# ## Установка зависимостей

# %%
# !pip install sentencepiece
# !pip install umap-learn
# !pip install gdown
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (0.1.96)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.7/dist-packages (0.5.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.0.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.21.6)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.5.7)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.51.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from umap-learn) (4.64.0)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (0.34.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pynndescent>=0.5->umap-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (4.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.7.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.64.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.7.1)

# %% [markdown]
# ## Подключение библиотек

# %%
from string import punctuation
import math
import time
import os

import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from matplotlib import pyplot as plt
from umap import UMAP
import sentencepiece as spm

import torch
import torch.nn as nn
import torch.nn.functional as F

# %matplotlib inline

# %% [markdown]
# ## Где взять датасеты
# * https://nlpub.ru/Ресурсы - русские наборы данных
#
# * https://huggingface.co/datasets - мультиязычные наборы данных
#
# * https://avidreaders.ru/books/ - книги в txt
#
# * https://z-lib.org/ - книги в pdf, txt
#
# * https://pdftotext.com/ - онлайн конвертер из pdf в txt

# %% [markdown]
# ## Загрузка необработанного корпуса

# %%
# !gdown --id 1MO6aev-2UUpZlwF0o4ZVGvQLi1YfZhck
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1MO6aev-2UUpZlwF0o4ZVGvQLi1YfZhck
# To: /content/prestuplenie-i-nakazanie.txt
# 100% 1.28M/1.28M [00:00<00:00, 173MB/s]

# %% [markdown]
# ## Очистка корпуса от пунктуации

# %%
def filter_punctuation(x):
    table = str.maketrans('', '', punctuation)
    x = map(lambda x: x.lower(), x)
    x = map(lambda x: x.translate(table), x)
    x = filter(lambda x: len(x)>0, x)
    return list(x)

FILENAME = '1984_new.txt' 
corpus = []
# encoding может быть один из ['ascii', 'utf-8', 'cp1251']
with open(FILENAME, 'r',
          encoding='utf-8') as f:
    for line in f:
        corpus.extend(list(filter(lambda x: len(x)>0, line.split())))

corpus = filter_punctuation(corpus)
with open('corpus.txt', 'w') as f:
    f.write('\n'.join(corpus))
corpus_df = pd.Series(corpus)
corpus_df.value_counts().head(50).plot(kind='bar', figsize=(10, 4))

# %% [markdown]
# ## Вывод наиболее частых слов

# %%
pd.Series(corpus).value_counts()
# Out:
# —           2424
# и           2398
# в           1960
# не          1697
# он          1343
#             ...
# подписал       1
# смертный       1
# приговор       1
# муки           1
# одержал        1
# Length: 18139, dtype: int64

# %% [markdown]
# ## Обучение токенизатора на корпусе текста
# Используется алгоритм [WordPiece](https://paperswithcode.com/method/wordpiece)

# %%
spm.SentencePieceTrainer.train(input='corpus.txt', model_prefix='m',
                               vocab_size=8389)

# %% [markdown]
# ## Проверка токенизатора

# %%
sp = spm.SentencePieceProcessor(model_file='m.model')
prompt = 'это пример токенизации текста'
print(sp.encode_as_ids(prompt)) # == sp.encode 
print(sp.encode_as_pieces(prompt))
# Out:
# [27, 1603, 53, 3716, 4099, 5, 5116, 1647]
# ['▁это', '▁пример', '▁то', 'кен', 'изаци', 'и', '▁тек', 'ста']

# %% [markdown]
# ## Получение словаря токенов

# %%
vocabs = [[sp.id_to_piece(id), id] for id in range(sp.get_piece_size())]
vocabs[:20]
# Out:
# [['<unk>', 0],
#  ['<s>', 1],
#  ['</s>', 2],
#  ['▁', 3],
#  ['е', 4],
#  ['и', 5],
#  ['а', 6],
#  ['▁и', 7],
#  ['▁в', 8],
#  ['—', 9],
#  ['▁не', 10],
#  ['▁он', 11],
#  ['▁с', 12],
#  ['у', 13],
#  ['▁на', 14],
#  ['й', 15],
#  ['я', 16],
#  ['ся', 17],
#  ['▁что', 18],
#  ['м', 19]]

# %% [markdown]
# ## Создание набора данных для задачи Next Token Prediction

# %%
def get_window(x):
    XX.append(x.values.copy())
    return 0

WINDOW_SIZE = 16
XX = []
corpus_df = pd.DataFrame(np.concatenate(sp.encode(corpus)))
corpus_df.columns = ['token_ids']
corpus_df['ids'] = corpus_df['token_ids'].factorize(sort=True)[0]
corpus_df['ids'].rolling(WINDOW_SIZE+1).apply(get_window)
table = corpus_df[['token_ids', 'ids']].\
                 drop_duplicates().\
                 sort_values(['ids'], ascending=True).\
                 values
ids2token_ids = {v:k for k,v  in table}

# %%
data = np.uint16(XX)
X = data[:, :WINDOW_SIZE].copy()
y = data[:, WINDOW_SIZE:].copy()

indexes = np.random.permutation(y.size)
X = X[indexes].copy()
y = y[indexes].copy()
assert np.unique(X).size == np.unique(y).size, \
    'Уменьшите размер словаря при обучении токенизатора'

# %% [markdown]
# ## Обучение в Keras (прототипирование)

# %%
import tensorflow as tf

inp = tf.keras.layers.Input((WINDOW_SIZE,))
x = tf.keras.layers.Embedding(np.unique(X).size, output_dim=50)(inp)
#x = tf.keras.layers.LSTM(128, return_sequences=False)(x)
#x = tf.keras.layers.Lambda(lambda xx: tf.transpose(xx, perm=[0, 2, 1]))(x)
x = tf.keras.layers.Conv1D(128, (5,), strides=(2,), activation='relu')(x)
x = tf.keras.layers.Conv1D(256, (5,), strides=(2,), activation='relu')(x)
#x = tf.keras.layers.Lambda(lambda xx: tf.transpose(xx, perm=[0, 2, 1]))(x)
x = tf.keras.layers.GlobalAveragePooling1D()(x)
out = tf.keras.layers.Dense(np.unique(y).size, activation='softmax')(x)

model = tf.keras.models.Model(inp, out)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 16)]              0
#
#  embedding (Embedding)       (None, 16, 50)            416850
#
#  conv1d (Conv1D)             (None, 6, 128)            32128
#
#  conv1d_1 (Conv1D)           (None, 1, 256)            164096
#
#  global_average_pooling1d (G  (None, 256)              0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 8337)              2142609
#
# =================================================================
# Total params: 2,755,683
# Trainable params: 2,755,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam',
              metrics=['accuracy', tf.keras.metrics.SparseTopKCategoricalAccurac
# %%
model.save('model.h5')

# %%
model.get_weights()[0].shape
# Out:
# (8337, 50)

# %%
batch_size = 1024
preds = []
for i in tqdm(range(X.shape[0]//batch_size+1)):
    preds.append(model.predict(X[i*batch_size:(i+1)*batch_size].copy()).\
                 argsort(axis=-1)[:, -5:].copy())
preds = np.concatenate(preds)
# Out:
#   0%|          | 0/116 [00:00<?, ?it/s]

# %%
for i in range(preds.shape[1]):
    corpus_df['pred@%d'%(i+1)] = -1
    corpus_df.loc[WINDOW_SIZE:, 'pred@%d'%(i+1)] = preds[:,-i]
corpus_df.head(50)
# Out:
#     token_ids   ids  pred@1  pred@2  pred@3  pred@4  pred@5
# 0           3     1      -1      -1      -1      -1      -1
# 1           0     0      -1      -1      -1      -1      -1
# 2         679   675      -1      -1      -1      -1      -1
# 3           0     0      -1      -1      -1      -1      -1
# 4        5668  5642      -1      -1      -1      -1      -1
# 5        1399  1393      -1      -1      -1      -1      -1
# 6          39    37      -1      -1      -1      -1      -1
# 7         436   433      -1      -1      -1      -1      -1
# 8           5     3      -1      -1      -1      -1      -1
# 9        1906  1894      -1      -1      -1      -1      -1
# 10         49    47      -1      -1      -1      -1      -1
# 11         20    18      -1      -1      -1      -1      -1
# 12        504   501      -1      -1      -1      -1      -1
# 13        172   170      -1      -1      -1      -1      -1
# 14       4500  4481      -1      -1      -1      -1      -1
# 15        254   252      -1      -1      -1      -1      -1
# 16          5     3       8       5       9       1       6
# 17        295   293     968    2766    1072    1626      85
# 18          0     0      17      64      39      54      23
# 19       4081  4063       3       5       6       8      12
# 20         21    19     733    1813     234     232    1474
# 21       2092  2080      28      27       7      65      35
# 22       5516  5490     336      43      77       7      10
# 23         47    45     146      49      29      63      61
# 24          3     1    3420    6078     215     380     120
# 25       6738  6712      15       9       1      29       5
# 26       2642  2626     583    5686     297     259    2380
# 27       6738  6712    1727     965     806    2573     502
# 28       1564  1555       5       6      10       8      12
# 29       2105  2093      13       2       3       4      14
# 30        652   648      58      25      62      16       8
# 31       6907  6879      12       6       5      10       8
# 32         44    42    4362     939     603     684     114
# 33        936   931    6632    5975    1670     564    1382
# 34        405   402      72     492      82      53     166
# 35       6637  6611       1       5      10       9      12
# 36        196   194       2       9       5       3       4
# 37        823   818      20       2       3       4      13
# 38         16    14     139     553     109     356      61
# 39       1449  1441      62     148      27      40      59
# 40        254   252     284    6285     569    1127     132
# 41          5     3      26      18      17       2      23
# 42          3     1      31      78      88      35      33
# 43          0     0    1657    1343      93     553     556
# 44        679   675    1183     412     533       0      35
# 45          0     0      18      21      75     105      71
# 46        679   675      24       1      77       7       9
# 47          0     0    6722    3715    2538    1787    4199
# 48        679   675      51     137       9      49      29
# 49          0     0      45      71     120     160     241

# %%
for col in corpus_df.columns[-preds.shape[1]:]:
    corpus_df[col] = corpus_df[col].apply(lambda x: ids2token_ids.get(x, -1))

# %%
sp.decode(corpus_df['pred@1'].tolist()[WINDOW_SIZE:])
#(corpus_df.token_ids==corpus_df[corpus_df.columns[-preds.shape[1]:]])
ицоя вы работа а и о не расе не чтоая этого какие  он и к ужасноили боль сго всяко прочиить на он пока неви и нами они в отили ты не вам рядо с которыных все отетя зна себ сже в...я сможетвой рас на всем какой идеее только в вяхой и сам поднялям таким высши джули а ккой однотьцо шесть всеы  и он черны и чтоными долженойе если дл он ниче слово работал поизнают по что могу другнуть все переменили всего лицол же когдаа сел дл к им пор с л ...

# %%
#from sklearn.decomposition import PCA
embeddings = UMAP(n_components=2, random_state=2).\
                                          fit_transform(model.get_weights()[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
fig, ax = plt.subplots(figsize=(20, 20))
ax.scatter(embeddings[:, 0], embeddings[:, 1], s=0.5, alpha=0.4)

whitelist = frozenset(corpus_df.token_ids.value_counts().index[:300].values)
for i, txt in enumerate(embeddings):
    token_id = ids2token_ids[i]
    if token_id not in whitelist:
        continue
    ax.annotate(vocabs[token_id][0],
                (embeddings[i][0], embeddings[i][1]))
plt.savefig('vecs.svg')

# %% [markdown]
# ## Обучение в Pytorch
# пример основан на
#
# https://github.com/pytorch/examples/tree/master/word_language_model

# %%
class ConvModel(nn.Module):
    """Container module with an encoder, a convolutional module, and a decoder."""

    def __init__(self, ntoken, ninp, nhid, dropout=0.1, tie_weights=False):
        super(ConvModel, self).__init__()
        self.ntoken = ntoken
        self.drop = nn.Dropout(dropout)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.conv = nn.Sequential(
                    nn.Conv1d(ninp, nhid//2, 5, stride=3, padding=2, dilation=1),
                    nn.ReLU(),
                    nn.Conv1d(nhid//2, nhid, 5, stride=3, padding=2, dilation=1),
                    nn.ReLU(),
                    nn.Conv1d(nhid, nhid*2, 5, stride=3, padding=2, dilation=1),
                    nn.ReLU(),
                    )
        self.decoder = nn.Linear(nhid*2, ntoken)

        self.init_weights()

        self.nhid = nhid
        self.model_type = 'Conv'

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.encoder.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.bias)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, inputs):
        emb = self.drop(self.encoder(inputs))
        emb = emb.transpose(2, 1)
        output = self.conv(emb)
        #print(output.size())
        output = self.drop(output)
        output = output.transpose(2, 1)
        decoded = self.decoder(output)
        #print(decoded.size())
        decoded = decoded.view(-1, self.ntoken)
        return F.log_softmax(decoded, dim=1)


class RNNModel(nn.Module):
    """Container module with an encoder, a recurrent module, and a decoder."""

    def __init__(self, rnn_type, ntoken, ninp, nhid, nlayers, dropout=0.1, tie_weights=False):
        super(RNNModel, self).__init__()
        self.ntoken = ntoken
        self.drop = nn.Dropout(dropout)
        self.encoder = nn.Embedding(ntoken, ninp)
        if rnn_type in ['LSTM', 'GRU']:
            self.rnn = getattr(nn, rnn_type)(ninp, nhid, nlayers, dropout=dropout)
        else:
            try:
                nonlinearity = {'RNN_TANH': 'tanh', 'RNN_RELU': 'relu'}[rnn_type]
            except KeyError:
                raise ValueError( """An invalid option for `--model` was supplied,
                                 options are ['LSTM', 'GRU', 'RNN_TANH' or 'RNN_RELU']""")
            self.rnn = nn.RNN(ninp, nhid, nlayers, nonlinearity=nonlinearity, dropout=dropout)
        self.decoder = nn.Linear(nhid, ntoken)

        # Optionally tie weights as in:
        # "Using the Output Embedding to Improve Language Models" (Press & Wolf 2016)
        # https://arxiv.org/abs/1608.05859
        # and
        # "Tying Word Vectors and Word Classifiers: A Loss Framework for Language Modeling" (Inan et al. 2016)
        # https://arxiv.org/abs/1611.01462
        if tie_weights:
            if nhid != ninp:
                raise ValueError('When using the tied flag, nhid must be equal to emsize')
            self.decoder.weight = self.encoder.weight

        self.init_weights()

        self.rnn_type = rnn_type
        self.nhid = nhid
        self.nlayers = nlayers

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.encoder.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.bias)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, input, hidden):
        emb = self.drop(self.encoder(input))
        output, hidden = self.rnn(emb, hidden)
        output = self.drop(output)
        decoded = self.decoder(output)
        decoded = decoded.view(-1, self.ntoken)
        return F.log_softmax(decoded, dim=1), hidden

    def init_hidden(self, bsz):
        weight = next(self.parameters())
        if self.rnn_type == 'LSTM':
            return (weight.new_zeros(self.nlayers, bsz, self.nhid),
                    weight.new_zeros(self.nlayers, bsz, self.nhid))
        else:
            return weight.new_zeros(self.nlayers, bsz, self.nhid)

# Temporarily leave PositionalEncoding module here. Will be moved somewhere else.
class PositionalEncoding(nn.Module):
    r"""Inject some information about the relative or absolute position of the tokens in the sequence.
        The positional encodings have the same dimension as the embeddings, so that the two can be summed.
        Here, we use sine and cosine functions of different frequencies.
    .. math:
        \text{PosEncoder}(pos, 2i) = sin(pos/10000^(2i/d_model))
        \text{PosEncoder}(pos, 2i+1) = cos(pos/10000^(2i/d_model))
        \text{where pos is the word position and i is the embed idx)
    Args:
        d_model: the embed dim (required).
        dropout: the dropout value (default=0.1).
        max_len: the max. length of the incoming sequence (default=5000).
    Examples:
        >>> pos_encoder = PositionalEncoding(d_model)
    """

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        r"""Inputs of forward function
        Args:
            x: the sequence fed to the positional encoder model (required).
        Shape:
            x: [sequence length, batch size, embed dim]
            output: [sequence length, batch size, embed dim]
        Examples:
            >>> output = pos_encoder(x)
        """

        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class TransformerModel(nn.Module):
    """Container module with an encoder, a recurrent or transformer module, and a decoder."""

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.1):
        super(TransformerModel, self).__init__()
        try:
            from torch.nn import TransformerEncoder, TransformerEncoderLayer
        except:
            raise ImportError('TransformerEncoder module does not exist in PyTorch 1.1 or lower.')
        self.model_type = 'Transformer'
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        # https://github.com/pytorch/pytorch/issues/28508
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        nn.init.uniform_(self.encoder.weight, -initrange, initrange)
        nn.init.zeros_(self.decoder.bias)
        nn.init.uniform_(self.decoder.weight, -initrange, initrange)

    def forward(self, src, has_mask=True):
        if has_mask:
            device = src.device
            if self.src_mask is None or self.src_mask.size(0) != len(src):
                mask = self._generate_square_subsequent_mask(len(src)).to(device)
                self.src_mask = mask
        else:
            self.src_mask = None
        #src = src.type(torch.int64)
        
        src = self.encoder(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, self.src_mask)
        output = self.decoder(output)
        return F.log_softmax(output, dim=-1)

# %%
###############################################################################
# Training code
###############################################################################

def repackage_hidden(h):
    """Wraps hidden states in new Tensors, to detach them from their history."""

    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)


# get_batch subdivides the source data into chunks of length args.bptt.
# If source is equal to the example output of the batchify function, with
# a bptt-limit of 2, we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the batchify function. The chunks are along dimension 0, corresponding
# to the seq_len dimension in the LSTM.

def get_batch(source, i):
    seq_len = min(bptt, len(y) - 1 - i)
    return torch.LongTensor(X[i:i+seq_len].astype(np.int32)).to(device), \
           torch.LongTensor(y[i:i+seq_len].astype(np.int32)).to(device)


def evaluate(data_source):
    # Turn on evaluation mode which disables dropout.
    model.eval()
    total_loss = 0.
    ntokens = np.unique(y).size
    model_types = frozenset(['Transformer', 'Conv'])

    if model_type not in model_types:
        hidden = model.init_hidden(WINDOW_SIZE)
    with torch.no_grad():
        for i in range(0, y.size - 1, bptt):
            data, targets = get_batch(y, i)
            if model_type == 'Transformer':
                output = model(data)
                output = output[:, -1, :]
            elif model_type == 'Conv':
                output = model(data)
                output = output.view(data.size()[0], -1, ntokens)[:, -1]
            else:
                output, hidden = model(data, hidden)
                hidden = repackage_hidden(hidden)
                output = output.view(-1, WINDOW_SIZE, ntokens)[:, -1]
            #print(output.size())
            total_loss += len(data) * criterion(output, targets.squeeze(1)).item()
    return total_loss / (len(data_source) - 1)


def train(batch_size=128):
    # Turn on training mode which enables dropout.
    model.train()
    total_loss = 0.
    start_time = time.time()
    ntokens = np.unique(y).size
    model_types = frozenset(['Transformer', 'Conv'])
    if model_type not in model_types:
        hidden = model.init_hidden(WINDOW_SIZE)
    for batch, i in enumerate(range(0, y.size - 1, bptt)):
        data, targets = get_batch(y, i)
        # Starting each batch, we detach the hidden state from how it was previously produced.
        # If we didn't, the model would try backpropagating all the way to start of the dataset.
        model.zero_grad()
        if model_type == 'Transformer':
            output = model(data)
            #output = output.view(-1, ntokens)
            output = output[:, -1]
        elif model_type == 'Conv':
            output = model(data)
            output = output.view(data.size()[0], -1, ntokens)[:, -1]
        else:
            hidden = repackage_hidden(hidden)
            output, hidden = model(data, hidden)
            output = output.view(-1, WINDOW_SIZE, ntokens)[:, -1]
        loss = criterion(output, targets.squeeze(1))
        loss.backward()

        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        for p in model.parameters():
            p.data.add_(p.grad, alpha=-lr)

        total_loss += loss.item()

        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.2f} | ms/batch {:5.3f} | '
                    'loss {:5.2f} | ppl {:8.2f}'.format(
                epoch, batch, len(y) // bptt, lr,
                elapsed * 1000 / log_interval, cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()
        if dry_run:
            break


def export_onnx(path, batch_size, seq_len):
    print('The model is also exported in ONNX format at {}.'.format(os.path.realpath(path)))
    model.eval()
    dummy_input = torch.LongTensor(seq_len * batch_size).zero_().view(-1, seq_len).to(device)
    inputs = dummy_input
    model_types = frozenset(['Transformer', 'Conv'])
    if model_type not in model_types:
        hidden = model.init_hidden(WINDOW_SIZE)
        inputs = (dummy_input, hidden)
    torch.onnx.export(model, inputs, path, opset_version=10)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Обучение свёрточной модели Conv1d

# %%
model = ConvModel(np.unique(y).size, 128, 192, 0.1).to(device)
criterion = nn.NLLLoss()
model
# Out:
# ConvModel(
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(8337, 128)
#   (conv): Sequential(
#     (0): Conv1d(128, 96, kernel_size=(5,), stride=(3,), padding=(2,))
#     (1): ReLU()
#     (2): Conv1d(96, 192, kernel_size=(5,), stride=(3,), padding=(2,))
#     (3): ReLU()
#     (4): Conv1d(192, 384, kernel_size=(5,), stride=(3,), padding=(2,))
#     (5): ReLU()
#   )
#   (decoder): Linear(in_features=384, out_features=8337, bias=True)
# )

# %%
model_type = 'Conv'
lr = 1
bptt = 64
eval_batch_size = bptt
clip = 0.1
log_interval = 100
dry_run = False

# %% [markdown]
# ### Вывод числа параметров

# %%
print(*[(k, p.view(-1).size()[0]) for k, p in model.named_parameters()],
      sep='\n')
print('Всего: {:,}'.format(sum(p.view(-1).size()[0] for k, p in model.named_parameters())))
# Out:
# ('encoder.weight', 1067136)
# ('conv.0.weight', 61440)
# ('conv.0.bias', 96)
# ('conv.2.weight', 92160)
# ('conv.2.bias', 192)
# ('conv.4.weight', 368640)
# ('conv.4.bias', 384)
# ('decoder.weight', 3201408)
# ('decoder.bias', 8337)
# Всего: 4,799,793

# %% [markdown]
# ### Проверка прямого прохода модели

# %%
model(torch.ones((32, 16)).type(torch.int64).to(device)).size()
# Out:
# torch.Size([32, 8337])

# %% [markdown]
# ### Замер времени прохождения по всему корпусу

# %%
# %%time
evaluate(y)
# Out:
# CPU times: user 1.67 s, sys: 5.91 ms, total: 1.68 s
# Wall time: 1.68 s
# 9.026488138294424

# %% [markdown]
# ### Обучение модели

# %%
# Loop over epochs.
epochs = 40
best_val_loss = None
savefile = '%s_next_token.pt'%model_type

patience_max = 1
patience = 0
# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, epochs+1):
        epoch_start_time = time.time()
        train()
        val_loss = evaluate(y)
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.3f} | '
                'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                           val_loss, math.exp(val_loss)))
        print('-' * 89)
        # Save the model if the validation loss is the best we've seen so far.
        if not best_val_loss or val_loss < best_val_loss:
            with open(savefile, 'wb') as f:
                torch.save(model, f)
            best_val_loss = val_loss
            patience = 0
        else:
            patience += 1
            if patience < patience_max: continue 
            with open(savefile, 'rb') as f:
                model = torch.load(f)
            # Anneal the learning rate if no improvement has been seen in the validation dataset.
            lr /= 2.0
            patience = 0
except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')
# Out:
# | epoch   1 |   100/ 1844 batches | lr 1.00 | ms/batch 4.087 | loss  8.20 | ppl  3633.15
# | epoch   1 |   200/ 1844 batches | lr 1.00 | ms/batch 3.975 | loss  7.20 | ppl  1343.80
# | epoch   1 |   300/ 1844 batches | lr 1.00 | ms/batch 3.894 | loss  7.08 | ppl  1183.85
# | epoch   1 |   400/ 1844 batches | lr 1.00 | ms/batch 3.872 | loss  6.96 | ppl  1057.44
# | epoch   1 |   500/ 1844 batches | lr 1.00 | ms/batch 4.000 | loss  6.95 | ppl  1044.33
# | epoch   1 |   600/ 1844 batches | lr 1.00 | ms/batch 3.906 | loss  6.88 | ppl   968.90
# | epoch   1 |   700/ 1844 batches | lr 1.00 | ms/batch 3.983 | loss  6.94 | ppl  1031.59
# | epoch   1 |   800/ 1844 batches | lr 1.00 | ms/batch 3.940 | loss  6.89 | ppl   984.93
# | epoch   1 |   900/ 1844 batches | lr 1.00 | ms/batch 3.895 | loss  6.87 | ppl   965.12
# | epoch   1 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.961 | loss  6.83 | ppl   922.28
# | epoch   1 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.938 | loss  6.91 | ppl  1006.01
# | epoch   1 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.984 | loss  6.88 | ppl   975.55
# | epoch   1 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.947 | loss  6.80 | ppl   894.49
# | epoch   1 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.914 | loss  6.81 | ppl   904.78
# | epoch   1 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.942 | loss  6.77 | ppl   869.02
# | epoch   1 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.941 | loss  6.80 | ppl   900.08
# | epoch   1 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.948 | loss  6.81 | ppl   910.93
# | epoch   1 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.978 | loss  6.80 | ppl   896.24
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  8.91s | valid loss 6.748 | valid ppl   852.40
# -----------------------------------------------------------------------------------------
# | epoch   2 |   100/ 1844 batches | lr 1.00 | ms/batch 4.001 | loss  6.84 | ppl   929.99
# | epoch   2 |   200/ 1844 batches | lr 1.00 | ms/batch 3.935 | loss  6.78 | ppl   880.32
# | epoch   2 |   300/ 1844 batches | lr 1.00 | ms/batch 4.081 | loss  6.77 | ppl   871.18
# | epoch   2 |   400/ 1844 batches | lr 1.00 | ms/batch 3.947 | loss  6.76 | ppl   859.23
# | epoch   2 |   500/ 1844 batches | lr 1.00 | ms/batch 3.973 | loss  6.78 | ppl   878.47
# | epoch   2 |   600/ 1844 batches | lr 1.00 | ms/batch 3.963 | loss  6.73 | ppl   840.33
# | epoch   2 |   700/ 1844 batches | lr 1.00 | ms/batch 3.901 | loss  6.81 | ppl   904.78
# | epoch   2 |   800/ 1844 batches | lr 1.00 | ms/batch 4.001 | loss  6.78 | ppl   878.36
# | epoch   2 |   900/ 1844 batches | lr 1.00 | ms/batch 3.990 | loss  6.77 | ppl   868.46
# | epoch   2 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.956 | loss  6.73 | ppl   833.19
# | epoch   2 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.978 | loss  6.81 | ppl   910.33
# | epoch   2 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.923 | loss  6.78 | ppl   883.43
# | epoch   2 |  1300/ 1844 batches | lr 1.00 | ms/batch 4.013 | loss  6.71 | ppl   817.56
# | epoch   2 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.959 | loss  6.70 | ppl   813.27
# | epoch   2 |  1500/ 1844 batches | lr 1.00 | ms/batch 4.017 | loss  6.67 | ppl   789.03
# | epoch   2 |  1600/ 1844 batches | lr 1.00 | ms/batch 4.026 | loss  6.71 | ppl   817.14
# | epoch   2 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.970 | loss  6.70 | ppl   815.35
# | epoch   2 |  1800/ 1844 batches | lr 1.00 | ms/batch 4.005 | loss  6.69 | ppl   807.02
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time:  8.97s | valid loss 6.640 | valid ppl   764.95
# -----------------------------------------------------------------------------------------
# | epoch   3 |   100/ 1844 batches | lr 1.00 | ms/batch 4.094 | loss  6.72 | ppl   825.45
# | epoch   3 |   200/ 1844 batches | lr 1.00 | ms/batch 3.919 | loss  6.66 | ppl   784.33
# | epoch   3 |   300/ 1844 batches | lr 1.00 | ms/batch 3.989 | loss  6.63 | ppl   756.04
# | epoch   3 |   400/ 1844 batches | lr 1.00 | ms/batch 3.921 | loss  6.62 | ppl   748.37
# | epoch   3 |   500/ 1844 batches | lr 1.00 | ms/batch 4.036 | loss  6.64 | ppl   765.68
# | epoch   3 |   600/ 1844 batches | lr 1.00 | ms/batch 4.041 | loss  6.58 | ppl   721.88
# | epoch   3 |   700/ 1844 batches | lr 1.00 | ms/batch 4.114 | loss  6.65 | ppl   776.51
# | epoch   3 |   800/ 1844 batches | lr 1.00 | ms/batch 4.000 | loss  6.60 | ppl   736.51
# | epoch   3 |   900/ 1844 batches | lr 1.00 | ms/batch 3.984 | loss  6.58 | ppl   717.63
# | epoch   3 |  1000/ 1844 batches | lr 1.00 | ms/batch 4.033 | loss  6.53 | ppl   687.33
# | epoch   3 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.980 | loss  6.62 | ppl   753.67
# | epoch   3 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.959 | loss  6.58 | ppl   717.15
# | epoch   3 |  1300/ 1844 batches | lr 1.00 | ms/batch 4.047 | loss  6.50 | ppl   663.17
# | epoch   3 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.972 | loss  6.48 | ppl   655.15
# | epoch   3 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.998 | loss  6.46 | ppl   636.82
# | epoch   3 |  1600/ 1844 batches | lr 1.00 | ms/batch 4.010 | loss  6.48 | ppl   654.80
# | epoch   3 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.966 | loss  6.49 | ppl   655.88
# | epoch   3 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.981 | loss  6.46 | ppl   640.29
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time:  8.98s | valid loss 6.406 | valid ppl   605.20
# -----------------------------------------------------------------------------------------
# | epoch   4 |   100/ 1844 batches | lr 1.00 | ms/batch 4.111 | loss  6.49 | ppl   657.25
# | epoch   4 |   200/ 1844 batches | lr 1.00 | ms/batch 3.966 | loss  6.44 | ppl   625.60
# | epoch   4 |   300/ 1844 batches | lr 1.00 | ms/batch 4.081 | loss  6.40 | ppl   603.68
# | epoch   4 |   400/ 1844 batches | lr 1.00 | ms/batch 4.047 | loss  6.39 | ppl   596.51
# | epoch   4 |   500/ 1844 batches | lr 1.00 | ms/batch 4.030 | loss  6.42 | ppl   611.66
# | epoch   4 |   600/ 1844 batches | lr 1.00 | ms/batch 4.050 | loss  6.37 | ppl   582.72
# | epoch   4 |   700/ 1844 batches | lr 1.00 | ms/batch 4.025 | loss  6.45 | ppl   634.22
# | epoch   4 |   800/ 1844 batches | lr 1.00 | ms/batch 4.044 | loss  6.40 | ppl   602.32
# | epoch   4 |   900/ 1844 batches | lr 1.00 | ms/batch 4.055 | loss  6.38 | ppl   589.30
# | epoch   4 |  1000/ 1844 batches | lr 1.00 | ms/batch 4.055 | loss  6.33 | ppl   563.37
# | epoch   4 |  1100/ 1844 batches | lr 1.00 | ms/batch 4.004 | loss  6.45 | ppl   630.51
# | epoch   4 |  1200/ 1844 batches | lr 1.00 | ms/batch 4.051 | loss  6.38 | ppl   592.16
# | epoch   4 |  1300/ 1844 batches | lr 1.00 | ms/batch 4.025 | loss  6.32 | ppl   554.92
# | epoch   4 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.978 | loss  6.32 | ppl   553.62
# | epoch   4 |  1500/ 1844 batches | lr 1.00 | ms/batch 4.010 | loss  6.30 | ppl   543.17
# | epoch   4 |  1600/ 1844 batches | lr 1.00 | ms/batch 4.018 | loss  6.33 | ppl   559.72
# | epoch   4 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.976 | loss  6.33 | ppl   562.70
# | epoch   4 |  1800/ 1844 batches | lr 1.00 | ms/batch 4.006 | loss  6.32 | ppl   557.33
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time:  9.03s | valid loss 6.263 | valid ppl   524.81
# -----------------------------------------------------------------------------------------
# | epoch   5 |   100/ 1844 batches | lr 1.00 | ms/batch 4.180 | loss  6.36 | ppl   575.75
# | epoch   5 |   200/ 1844 batches | lr 1.00 | ms/batch 3.971 | loss  6.32 | ppl   554.71
# | epoch   5 |   300/ 1844 batches | lr 1.00 | ms/batch 4.045 | loss  6.28 | ppl   532.52
# | epoch   5 |   400/ 1844 batches | lr 1.00 | ms/batch 3.939 | loss  6.27 | ppl   529.93
# | epoch   5 |   500/ 1844 batches | lr 1.00 | ms/batch 3.959 | loss  6.31 | ppl   548.07
# | epoch   5 |   600/ 1844 batches | lr 1.00 | ms/batch 4.027 | loss  6.26 | ppl   521.37
# | epoch   5 |   700/ 1844 batches | lr 1.00 | ms/batch 3.975 | loss  6.35 | ppl   571.36
# | epoch   5 |   800/ 1844 batches | lr 1.00 | ms/batch 3.990 | loss  6.31 | ppl   547.78
# | epoch   5 |   900/ 1844 batches | lr 1.00 | ms/batch 4.009 | loss  6.27 | ppl   529.21
# | epoch   5 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.981 | loss  6.24 | ppl   513.39
# | epoch   5 |  1100/ 1844 batches | lr 1.00 | ms/batch 4.078 | loss  6.35 | ppl   570.85
# | epoch   5 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.993 | loss  6.29 | ppl   536.54
# | epoch   5 |  1300/ 1844 batches | lr 1.00 | ms/batch 4.040 | loss  6.21 | ppl   499.15
# | epoch   5 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.976 | loss  6.23 | ppl   508.02
# | epoch   5 |  1500/ 1844 batches | lr 1.00 | ms/batch 4.015 | loss  6.22 | ppl   500.64
# | epoch   5 |  1600/ 1844 batches | lr 1.00 | ms/batch 4.050 | loss  6.24 | ppl   511.83
# | epoch   5 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.967 | loss  6.25 | ppl   517.09
# | epoch   5 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.980 | loss  6.24 | ppl   512.76
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time:  8.99s | valid loss 6.181 | valid ppl   483.62
# -----------------------------------------------------------------------------------------
# | epoch   6 |   100/ 1844 batches | lr 1.00 | ms/batch 4.069 | loss  6.28 | ppl   531.15
# | epoch   6 |   200/ 1844 batches | lr 1.00 | ms/batch 3.937 | loss  6.24 | ppl   510.40
# | epoch   6 |   300/ 1844 batches | lr 1.00 | ms/batch 4.033 | loss  6.20 | ppl   492.58
# | epoch   6 |   400/ 1844 batches | lr 1.00 | ms/batch 3.964 | loss  6.20 | ppl   490.82
# | epoch   6 |   500/ 1844 batches | lr 1.00 | ms/batch 3.972 | loss  6.23 | ppl   508.47
# | epoch   6 |   600/ 1844 batches | lr 1.00 | ms/batch 4.001 | loss  6.18 | ppl   483.46
# | epoch   6 |   700/ 1844 batches | lr 1.00 | ms/batch 3.956 | loss  6.27 | ppl   526.43
# | epoch   6 |   800/ 1844 batches | lr 1.00 | ms/batch 3.965 | loss  6.23 | ppl   509.24
# | epoch   6 |   900/ 1844 batches | lr 1.00 | ms/batch 3.994 | loss  6.20 | ppl   491.61
# | epoch   6 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.959 | loss  6.17 | ppl   476.00
# | epoch   6 |  1100/ 1844 batches | lr 1.00 | ms/batch 4.047 | loss  6.28 | ppl   532.85
# | epoch   6 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.962 | loss  6.22 | ppl   501.66
# | epoch   6 |  1300/ 1844 batches | lr 1.00 | ms/batch 4.022 | loss  6.15 | ppl   466.39
# | epoch   6 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.979 | loss  6.16 | ppl   473.48
# | epoch   6 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.952 | loss  6.14 | ppl   464.46
# | epoch   6 |  1600/ 1844 batches | lr 1.00 | ms/batch 4.045 | loss  6.17 | ppl   479.78
# | epoch   6 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.964 | loss  6.18 | ppl   481.17
# | epoch   6 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.951 | loss  6.17 | ppl   476.90
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time:  8.96s | valid loss 6.112 | valid ppl   451.30
# -----------------------------------------------------------------------------------------
# | epoch   7 |   100/ 1844 batches | lr 1.00 | ms/batch 4.026 | loss  6.22 | ppl   501.51
# | epoch   7 |   200/ 1844 batches | lr 1.00 | ms/batch 3.973 | loss  6.18 | ppl   481.92
# | epoch   7 |   300/ 1844 batches | lr 1.00 | ms/batch 4.005 | loss  6.13 | ppl   460.10
# | epoch   7 |   400/ 1844 batches | lr 1.00 | ms/batch 3.942 | loss  6.13 | ppl   461.40
# | epoch   7 |   500/ 1844 batches | lr 1.00 | ms/batch 4.009 | loss  6.17 | ppl   477.81
# | epoch   7 |   600/ 1844 batches | lr 1.00 | ms/batch 3.964 | loss  6.11 | ppl   451.75
# | epoch   7 |   700/ 1844 batches | lr 1.00 | ms/batch 3.993 | loss  6.20 | ppl   494.99
# | epoch   7 |   800/ 1844 batches | lr 1.00 | ms/batch 3.903 | loss  6.17 | ppl   479.23
# | epoch   7 |   900/ 1844 batches | lr 1.00 | ms/batch 3.938 | loss  6.14 | ppl   464.85
# | epoch   7 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.995 | loss  6.10 | ppl   446.68
# | epoch   7 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.959 | loss  6.22 | ppl   502.85
# | epoch   7 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.974 | loss  6.16 | ppl   472.78
# | epoch   7 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.987 | loss  6.09 | ppl   439.73
# | epoch   7 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.982 | loss  6.10 | ppl   444.71
# | epoch   7 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.928 | loss  6.09 | ppl   439.91
# | epoch   7 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.940 | loss  6.11 | ppl   451.18
# | epoch   7 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.939 | loss  6.12 | ppl   456.05
# | epoch   7 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.976 | loss  6.12 | ppl   453.84
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time:  8.92s | valid loss 6.050 | valid ppl   424.24
# -----------------------------------------------------------------------------------------
# | epoch   8 |   100/ 1844 batches | lr 1.00 | ms/batch 3.986 | loss  6.16 | ppl   473.24
# | epoch   8 |   200/ 1844 batches | lr 1.00 | ms/batch 3.907 | loss  6.11 | ppl   452.36
# | epoch   8 |   300/ 1844 batches | lr 1.00 | ms/batch 3.955 | loss  6.07 | ppl   434.53
# | epoch   8 |   400/ 1844 batches | lr 1.00 | ms/batch 3.931 | loss  6.08 | ppl   438.13
# | epoch   8 |   500/ 1844 batches | lr 1.00 | ms/batch 4.033 | loss  6.11 | ppl   452.00
# | epoch   8 |   600/ 1844 batches | lr 1.00 | ms/batch 4.001 | loss  6.07 | ppl   431.43
# | epoch   8 |   700/ 1844 batches | lr 1.00 | ms/batch 3.976 | loss  6.15 | ppl   466.40
# | epoch   8 |   800/ 1844 batches | lr 1.00 | ms/batch 4.029 | loss  6.12 | ppl   452.97
# | epoch   8 |   900/ 1844 batches | lr 1.00 | ms/batch 3.950 | loss  6.08 | ppl   436.00
# | epoch   8 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.924 | loss  6.06 | ppl   427.30
# | epoch   8 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.925 | loss  6.17 | ppl   479.90
# | epoch   8 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.934 | loss  6.10 | ppl   447.77
# | epoch   8 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.905 | loss  6.03 | ppl   417.35
# | epoch   8 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.940 | loss  6.05 | ppl   424.72
# | epoch   8 |  1500/ 1844 batches | lr 1.00 | ms/batch 4.041 | loss  6.03 | ppl   415.76
# | epoch   8 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.973 | loss  6.07 | ppl   430.76
# | epoch   8 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.953 | loss  6.07 | ppl   430.92
# | epoch   8 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.978 | loss  6.07 | ppl   432.59
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time:  8.93s | valid loss 5.996 | valid ppl   401.88
# -----------------------------------------------------------------------------------------
# | epoch   9 |   100/ 1844 batches | lr 1.00 | ms/batch 4.041 | loss  6.12 | ppl   452.96
# | epoch   9 |   200/ 1844 batches | lr 1.00 | ms/batch 3.974 | loss  6.07 | ppl   432.25
# | epoch   9 |   300/ 1844 batches | lr 1.00 | ms/batch 3.968 | loss  6.02 | ppl   413.27
# | epoch   9 |   400/ 1844 batches | lr 1.00 | ms/batch 3.916 | loss  6.02 | ppl   413.55
# | epoch   9 |   500/ 1844 batches | lr 1.00 | ms/batch 3.993 | loss  6.07 | ppl   430.96
# | epoch   9 |   600/ 1844 batches | lr 1.00 | ms/batch 3.919 | loss  6.02 | ppl   411.70
# | epoch   9 |   700/ 1844 batches | lr 1.00 | ms/batch 3.917 | loss  6.10 | ppl   446.32
# | epoch   9 |   800/ 1844 batches | lr 1.00 | ms/batch 3.980 | loss  6.07 | ppl   431.81
# | epoch   9 |   900/ 1844 batches | lr 1.00 | ms/batch 3.927 | loss  6.04 | ppl   418.33
# | epoch   9 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.995 | loss  6.01 | ppl   407.70
# | epoch   9 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.987 | loss  6.12 | ppl   454.19
# | epoch   9 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.971 | loss  6.07 | ppl   431.07
# | epoch   9 |  1300/ 1844 batches | lr 1.00 | ms/batch 4.022 | loss  5.99 | ppl   397.53
# | epoch   9 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.954 | loss  5.99 | ppl   400.98
# | epoch   9 |  1500/ 1844 batches | lr 1.00 | ms/batch 4.133 | loss  5.98 | ppl   397.07
# | epoch   9 |  1600/ 1844 batches | lr 1.00 | ms/batch 4.068 | loss  6.02 | ppl   409.83
# | epoch   9 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.971 | loss  6.02 | ppl   412.32
# | epoch   9 |  1800/ 1844 batches | lr 1.00 | ms/batch 4.023 | loss  6.02 | ppl   411.11
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time:  8.95s | valid loss 5.946 | valid ppl   382.07
# -----------------------------------------------------------------------------------------
# | epoch  10 |   100/ 1844 batches | lr 1.00 | ms/batch 4.010 | loss  6.07 | ppl   433.84
# | epoch  10 |   200/ 1844 batches | lr 1.00 | ms/batch 3.947 | loss  6.02 | ppl   411.05
# | epoch  10 |   300/ 1844 batches | lr 1.00 | ms/batch 4.074 | loss  5.98 | ppl   396.01
# | epoch  10 |   400/ 1844 batches | lr 1.00 | ms/batch 3.929 | loss  5.97 | ppl   393.19
# | epoch  10 |   500/ 1844 batches | lr 1.00 | ms/batch 4.023 | loss  6.02 | ppl   410.89
# | epoch  10 |   600/ 1844 batches | lr 1.00 | ms/batch 3.975 | loss  5.97 | ppl   392.22
# | epoch  10 |   700/ 1844 batches | lr 1.00 | ms/batch 3.897 | loss  6.05 | ppl   425.35
# | epoch  10 |   800/ 1844 batches | lr 1.00 | ms/batch 3.977 | loss  6.02 | ppl   411.25
# | epoch  10 |   900/ 1844 batches | lr 1.00 | ms/batch 3.919 | loss  5.99 | ppl   399.34
# | epoch  10 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.952 | loss  5.96 | ppl   389.00
# | epoch  10 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.986 | loss  6.08 | ppl   437.50
# | epoch  10 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.910 | loss  6.02 | ppl   410.99
# | epoch  10 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.966 | loss  5.94 | ppl   378.70
# | epoch  10 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.939 | loss  5.95 | ppl   385.61
# | epoch  10 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.952 | loss  5.94 | ppl   381.21
# | epoch  10 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.983 | loss  5.98 | ppl   393.73
# | epoch  10 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.943 | loss  5.98 | ppl   393.59
# | epoch  10 |  1800/ 1844 batches | lr 1.00 | ms/batch 4.028 | loss  5.99 | ppl   398.28
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time:  8.93s | valid loss 5.904 | valid ppl   366.42
# -----------------------------------------------------------------------------------------
# | epoch  11 |   100/ 1844 batches | lr 1.00 | ms/batch 4.039 | loss  6.03 | ppl   415.21
# | epoch  11 |   200/ 1844 batches | lr 1.00 | ms/batch 3.909 | loss  5.98 | ppl   393.88
# | epoch  11 |   300/ 1844 batches | lr 1.00 | ms/batch 3.938 | loss  5.94 | ppl   379.03
# | epoch  11 |   400/ 1844 batches | lr 1.00 | ms/batch 3.963 | loss  5.93 | ppl   376.88
# | epoch  11 |   500/ 1844 batches | lr 1.00 | ms/batch 3.968 | loss  5.98 | ppl   394.76
# | epoch  11 |   600/ 1844 batches | lr 1.00 | ms/batch 3.996 | loss  5.94 | ppl   379.27
# | epoch  11 |   700/ 1844 batches | lr 1.00 | ms/batch 4.015 | loss  6.01 | ppl   406.06
# | epoch  11 |   800/ 1844 batches | lr 1.00 | ms/batch 3.976 | loss  5.98 | ppl   396.94
# | epoch  11 |   900/ 1844 batches | lr 1.00 | ms/batch 3.949 | loss  5.94 | ppl   381.75
# | epoch  11 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.971 | loss  5.93 | ppl   374.71
# | epoch  11 |  1100/ 1844 batches | lr 1.00 | ms/batch 4.169 | loss  6.03 | ppl   415.28
# | epoch  11 |  1200/ 1844 batches | lr 1.00 | ms/batch 4.148 | loss  5.98 | ppl   394.90
# | epoch  11 |  1300/ 1844 batches | lr 1.00 | ms/batch 4.147 | loss  5.90 | ppl   366.29
# | epoch  11 |  1400/ 1844 batches | lr 1.00 | ms/batch 4.105 | loss  5.91 | ppl   370.02
# | epoch  11 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.974 | loss  5.91 | ppl   366.91
# | epoch  11 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.968 | loss  5.93 | ppl   374.90
# | epoch  11 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.997 | loss  5.94 | ppl   379.30
# | epoch  11 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.975 | loss  5.94 | ppl   379.62
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time:  8.97s | valid loss 5.862 | valid ppl   351.46
# -----------------------------------------------------------------------------------------
# | epoch  12 |   100/ 1844 batches | lr 1.00 | ms/batch 3.984 | loss  5.99 | ppl   399.55
# | epoch  12 |   200/ 1844 batches | lr 1.00 | ms/batch 3.912 | loss  5.94 | ppl   379.79
# | epoch  12 |   300/ 1844 batches | lr 1.00 | ms/batch 3.976 | loss
 1844 batches | lr 1.00 | ms/batch 3.952 | loss  5.86 | ppl   352.43
# | epoch  14 |   600/ 1844 batches | lr 1.00 | ms/batch 3.922 | loss  5.82 | ppl   337.36
# | epoch  14 |   700/ 1844 batches | lr 1.00 | ms/batch 3.954 | loss  5.89 | ppl   360.46
# | epoch  14 |   800/ 1844 batches | lr 1.00 | ms/batch 3.991 | loss  5.87 | ppl   353.19
# | epoch  14 |   900/ 1844 batches | lr 1.00 | ms/batch 3.931 | loss  5.83 | ppl   341.92
# | epoch  14 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.956 | loss  5.80 | ppl   331.61
# | epoch  14 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.936 | loss  5.92 | ppl   371.99
# | epoch  14 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.932 | loss  5.87 | ppl   354.91
# | epoch  14 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.989 | loss  5.79 | ppl   325.53
# | epoch  14 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.893 | loss  5.80 | ppl   330.92
# | epoch  14 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.951 | loss  5.79 | ppl   325.57
# | epoch  14 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.959 | loss  5.82 | ppl   338.29
# | epoch  14 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.937 | loss  5.82 | ppl   338.44
# | epoch  14 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.972 | loss  5.83 | ppl   338.76
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time:  8.87s | valid loss 5.743 | valid ppl   311.89
# -----------------------------------------------------------------------------------------
# | epoch  15 |   100/ 1844 batches | lr 1.00 | ms/batch 4.060 | loss  5.88 | ppl   358.33
# | epoch  15 |   200/ 1844 batches | lr 1.00 | ms/batch 3.958 | loss  5.83 | ppl   340.88
# | epoch  15 |   300/ 1844 batches | lr 1.00 | ms/batch 3.980 | loss  5.79 | ppl   326.04
# | epoch  15 |   400/ 1844 batches | lr 1.00 | ms/batch 3.941 | loss  5.79 | ppl   328.05
# | epoch  15 |   500/ 1844 batches | lr 1.00 | ms/batch 3.936 | loss  5.83 | ppl   341.82
# | epoch  15 |   600/ 1844 batches | lr 1.00 | ms/batch 3.950 | loss  5.80 | ppl   329.26
# | epoch  15 |   700/ 1844 batches | lr 1.00 | ms/batch 3.965 | loss  5.86 | ppl   349.09
# | epoch  15 |   800/ 1844 batches | lr 1.00 | ms/batch 4.011 | loss  5.83 | ppl   340.81
# | epoch  15 |   900/ 1844 batches | lr 1.00 | ms/batch 4.024 | loss  5.80 | ppl   330.88
# | epoch  15 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.987 | loss  5.76 | ppl   317.96
# | epoch  15 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.978 | loss  5.88 | ppl   359.31
# | epoch  15 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.959 | loss  5.84 | ppl   342.69
# | epoch  15 |  1300/ 1844 batches | lr 1.00 | ms/batch 4.007 | loss  5.75 | ppl   315.41
# | epoch  15 |  1400/ 1844 batches | lr 1.00 | ms/batch 4.001 | loss  5.78 | ppl   322.93
# | epoch  15 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.941 | loss  5.75 | ppl   313.63
# | epoch  15 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.999 | loss  5.78 | ppl   324.52
# | epoch  15 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.978 | loss  5.79 | ppl   327.78
# | epoch  15 |  1800/ 1844 batches | lr 1.00 | ms/batch 4.013 | loss  5.79 | ppl   328.56
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time:  8.95s | valid loss 5.704 | valid ppl   300.16
# -----------------------------------------------------------------------------------------
# | epoch  16 |   100/ 1844 batches | lr 1.00 | ms/batch 4.058 | loss  5.85 | ppl   345.73
# | epoch  16 |   200/ 1844 batches | lr 1.00 | ms/batch 3.955 | loss  5.80 | ppl   329.56
# | epoch  16 |   300/ 1844 batches | lr 1.00 | ms/batch 3.990 | loss  5.75 | ppl   313.09
# | epoch  16 |   400/ 1844 batches | lr 1.00 | ms/batch 3.940 | loss
|  1100/ 1844 batches | lr 1.00 | ms/batch 3.945 | loss  5.77 | ppl   322.13
# | epoch  18 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.968 | loss  5.73 | ppl   307.70
# | epoch  18 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.899 | loss  5.64 | ppl   281.84
# | epoch  18 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.934 | loss  5.66 | ppl   287.66
# | epoch  18 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.928 | loss  5.65 | ppl   285.16
# | epoch  18 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.943 | loss  5.69 | ppl   294.48
# | epoch  18 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.897 | loss  5.68 | ppl   292.85
# | epoch  18 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.956 | loss  5.69 | ppl   294.67
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time:  8.87s | valid loss 5.592 | valid ppl   268.35
# -----------------------------------------------------------------------------------------
# | epoch  19 |   100/ 1844 batches | lr 1.00 | ms/batch 3.987 | loss  5.74 | ppl   310.61
# | epoch  19 |   200/ 1844 batches | lr 1.00 | ms/batch 3.894 | loss  5.69 | ppl   295.18
# | epoch  19 |   300/ 1844 batches | lr 1.00 | ms/batch 3.976 | loss  5.65 | ppl   284.08
# | epoch  19 |   400/ 1844 batches | lr 1.00 | ms/batch 3.926 | loss  5.64 | ppl   282.46
# | epoch  19 |   500/ 1844 batches | lr 1.00 | ms/batch 3.898 | loss  5.69 | ppl   295.85
# | epoch  19 |   600/ 1844 batches | lr 1.00 | ms/batch 3.895 | loss  5.65 | ppl   284.91
# | epoch  19 |   700/ 1844 batches | lr 1.00 | ms/batch 3.880 | loss  5.70 | ppl   299.91
# | epoch  19 |   800/ 1844 batches | lr 1.00 | ms/batch 4.022 | loss  5.69 | ppl   295.52
# | epoch  19 |   900/ 1844 batches | lr 1.00 | ms/batch 3.952 | loss  5.66 | ppl   286.34
# | epoch  19 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.935 | loss  5.62 | ppl   275.14
# | epoch  19 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.886 | loss  5.74 | ppl   311.82
# | epoch  19 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.954 | loss  5.70 | ppl   299.05
# | epoch  19 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.962 | loss  5.61 | ppl   273.71
# | epoch  19 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.930 | loss  5.64 | ppl   280.22
# | epoch  19 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.926 | loss  5.62 | ppl   276.98
# | epoch  19 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.939 | loss  5.65 | ppl   285.32
# | epoch  19 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.909 | loss  5.65 | ppl   284.12
# | epoch  19 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.926 | loss  5.66 | ppl   285.81
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time:  8.87s | valid loss 5.555 | valid ppl   258.62
# -----------------------------------------------------------------------------------------
# | epoch  20 |   100/ 1844 batches | lr 1.00 | ms/batch 4.006 | loss  5.69 | ppl   297.34
# | epoch  20 |   200/ 1844 batches | lr 1.00 | ms/batch 3.943 | loss  5.66 | ppl   287.56
# | epoch  20 |   300/ 1844 batches | lr 1.00 | ms/batch 3.965 | loss  5.62 | ppl   274.52
# | epoch  20 |   400/ 1844 batches | lr 1.00 | ms/batch 3.953 | loss  5.62 | ppl   275.93
# | epoch  20 |   500/ 1844 batches | lr 1.00 | ms/batch 3.950 | loss  5.66 | ppl   286.38
# | epoch  20 |   600/ 1844 batches | lr 1.00 | ms/batch 3.931 | loss  5.62 | ppl   274.74
# | epoch  20 |   700/ 1844 batches | lr 1.00 | ms/batch 3.941 | loss  5.67 | ppl   289.21
# | epoch  20 |   800/ 1844 batches | lr 1.00 | ms/batch 3.967 | loss  5.65 | ppl   283.11
# | epoch  20 |   900/ 1844 batches | lr 1.00 | ms/batch 3.931 | loss  5.62 | ppl   277.24
# | epoch  20 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.935 | loss  5.58 | ppl   265.42
# | epoch  20 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.962 | loss  5.71 | ppl   301.93
# | epoch  20 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.975 | loss  5.66 | ppl   286.48
# | epoch  20 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.945 | loss  5.57 | ppl   262.41
# | epoch  20 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.978 | loss  5.61 | ppl   272.37
# | epoch  20 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.939 | loss  5.58 | ppl   265.59
# | epoch  20 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.949 | loss  5.62 | ppl   276.47
# | epoch  20 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.946 | loss  5.61 | ppl   272.65
# | epoch  20 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.928 | loss  5.62 | ppl   274.84
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time:  8.87s | valid loss 5.516 | valid ppl   248.74
# -----------------------------------------------------------------------------------------
# | epoch  21 |   100/ 1844 batches | lr 1.00 | ms/batch 4.031 | loss  5.67 | ppl   289.53
# | epoch  21 |   200/ 1844 batches | lr 1.00 | ms/batch 3.906 | loss  5.63 | ppl   277.35
# | epoch  21 |   300/ 1844 batches | lr 1.00 | ms/batch 3.942 | loss  5.58 | ppl   264.34
# | epoch  21 |   400/ 1844 batches | lr 1.00 | ms/batch 3.962 | loss  5.58 | ppl   266.14
# | epoch  21 |   500/ 1844 batches | lr 1.00 | ms/batch 3.938 | loss  5.62 | ppl   277.14
# | epoch  21 |   600/ 1844 batches | lr 1.00 | ms/batch 3.937 | loss  5.59 | ppl   267.64
# | epoch  21 |   700/ 1844 batches | lr 1.00 | ms/batch 3.977 | loss  5.63 | ppl   279.85
# | epoch  21 |   800/ 1844 batches | lr 1.00 | ms/batch 3.913 | loss  5.61 | ppl   274.19
# | epoch  21 |   900/ 1844 batches | lr 1.00 | ms/batch 3.976 | loss  5.60 | ppl   269.16
# | epoch  21 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.940 | loss  5.55 | ppl   256.86
# | epoch  21 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.905 | loss  5.67 | ppl   290.12
# | epoch  21 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.958 | loss  5.62 | ppl   275.90
# | epoch  21 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.953 | loss  5.54 | ppl   254.90
# | epoch  21 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.969 | loss  5.56 | ppl   260.99
# | epoch  21 |  1500/ 1844 batches | lr 1.00 | ms/batch 4.031 | loss  5.54 | ppl   255.02
# | epoch  21 |  1600/ 1844 batches | lr 1.00 | ms/batch 4.018 | loss  5.59 | ppl   267.92
# | epoch  21 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.967 | loss  5.58 | ppl   265.54
# | epoch  21 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.942 | loss  5.58 | ppl   265.18
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time:  8.90s | valid loss 5.479 | valid ppl   239.63
# -----------------------------------------------------------------------------------------
# | epoch  22 |   100/ 1844 batches | lr 1.00 | ms/batch 4.014 | loss  5.63 | ppl   279.03
# | epoch  22 |   200/ 1844 batches | lr 1.00 | ms/batch 4.049 | loss  5.59 | ppl   267.55
# | epoch  22 |   300/ 1844 batches | lr 1.00 | ms/batch 3.979 | loss  5.55 | ppl   257.09
# | epoch  22 |   400/ 1844 batches | lr 1.00 | ms/batch 4.000 | loss  5.55 | ppl   256.32
# | epoch  22 |   500/ 1844 batches | lr 1.00 | ms/batch 3.922 | loss  5.59 | ppl   268.88
# | epoch  22 |   600/ 1844 batches | lr 1.00 | ms/batch 3.929 | loss  5.55 | ppl   257.91
# | epoch  22 |   700/ 1844 batches | lr 1.00 | ms/batch 3.951 | loss  5.60 | ppl   270.45
# | epoch  22 |   800/ 1844 batches | lr 1.00 | ms/batch 3.940 | loss
 1844 batches | lr 1.00 | ms/batch 3.953 | loss  5.53 | ppl   252.68
# | epoch  24 |   800/ 1844 batches | lr 1.00 | ms/batch 4.015 | loss  5.52 | ppl   248.49
# | epoch  24 |   900/ 1844 batches | lr 1.00 | ms/batch 3.913 | loss  5.49 | ppl   241.76
# | epoch  24 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.961 | loss  5.45 | ppl   231.78
# | epoch  24 |  1100/ 1844 batches | lr 1.00 | ms/batch 4.009 | loss  5.57 | ppl   263.03
# | epoch  24 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.938 | loss  5.53 | ppl   252.85
# | epoch  24 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.983 | loss  5.44 | ppl   230.20
# | epoch  24 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.926 | loss  5.47 | ppl   237.20
# | epoch  24 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.982 | loss  5.44 | ppl   231.34
# | epoch  24 |  1600/ 1844 batches | lr 1.00 | ms/batch 4.013 | loss  5.49 | ppl   241.86
# | epoch  24 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.983 | loss  5.48 | ppl   240.07
# | epoch  24 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.946 | loss  5.48 | ppl   239.97
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time:  8.90s | valid loss 5.369 | valid ppl   214.56
# -----------------------------------------------------------------------------------------
# | epoch  25 |   100/ 1844 batches | lr 1.00 | ms/batch 4.107 | loss  5.53 | ppl   253.33
# | epoch  25 |   200/ 1844 batches | lr 1.00 | ms/batch 3.921 | loss  5.49 | ppl   241.45
# | epoch  25 |   300/ 1844 batches | lr 1.00 | ms/batch 4.069 | loss  5.44 | ppl   231.04
# | epoch  25 |   400/ 1844 batches | lr 1.00 | ms/batch 3.914 | loss  5.43 | ppl   228.49
# | epoch  25 |   500/ 1844 batches | lr 1.00 | ms/batch 3.943 | loss  5.50 | ppl   245.54
# | epoch  25 |   600/ 1844 batches | lr 1.00 | ms/batch 3.969 | loss  5.44 | ppl   231.06
# | epoch  25 |   700/ 1844 batches | lr 1.00 | ms/batch 3.890 | loss  5.50 | ppl   244.91
# | epoch  25 |   800/ 1844 batches | lr 1.00 | ms/batch 4.041 | loss  5.48 | ppl   240.36
# | epoch  25 |   900/ 1844 batches | lr 1.00 | ms/batch 3.958 | loss  5.46 | ppl   234.28
# | epoch  25 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.960 | loss  5.41 | ppl   223.86
# | epoch  25 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.957 | loss  5.54 | ppl   255.11
# | epoch  25 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.988 | loss  5.49 | ppl   242.92
# | epoch  25 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.931 | loss  5.42 | ppl   225.10
# | epoch  25 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.923 | loss  5.43 | ppl   228.29
# | epoch  25 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.957 | loss  5.41 | ppl   223.26
# | epoch  25 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.941 | loss  5.45 | ppl   231.94
# | epoch  25 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.888 | loss  5.46 | ppl   234.03
# | epoch  25 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.928 | loss  5.44 | ppl   231.15
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time:  8.88s | valid loss 5.335 | valid ppl   207.53
# -----------------------------------------------------------------------------------------
# | epoch  26 |   100/ 1844 batches | lr 1.00 | ms/batch 4.021 | loss  5.49 | ppl   241.23
# | epoch  26 |   200/ 1844 batches | lr 1.00 | ms/batch 3.893 | loss  5.45 | ppl   232.80
# | epoch  26 |   300/ 1844 batches | lr 1.00 | ms/batch 3.967 | loss  5.42 | ppl   226.68
# | epoch  26 |   400/ 1844 batches | lr 1.00 | ms/batch 3.952 | loss  5.41 | ppl   223.49
# | epoch  26 |   500/ 1844 batches | lr 1.00 | ms/batch 3.986 | loss  5.47 | ppl   237.05
# | epoch  26 |   600/ 1844 batches | lr 1.00 | ms/batch 3.945 | loss  5.40 | ppl   221.20
# | epoch  26 |   700/ 1844 batches | lr 1.00 | ms/batch 4.068 | loss  5.47 | ppl   236.29
# | epoch  26 |   800/ 1844 batches | lr 1.00 | ms/batch 3.987 | loss  5.45 | ppl   231.91
# | epoch  26 |   900/ 1844 batches | lr 1.00 | ms/batch 3.941 | loss  5.42 | ppl   226.39
# | epoch  26 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.957 | loss  5.38 | ppl   216.98
# | epoch  26 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.958 | loss  5.49 | ppl   241.95
# | epoch  26 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.940 | loss  5.46 | ppl   234.88
# | epoch  26 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.963 | loss  5.37 | ppl   214.52
# | epoch  26 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.944 | loss  5.40 | ppl   221.10
# | epoch  26 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.947 | loss  5.38 | ppl   217.77
# | epoch  26 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.956 | loss  5.40 | ppl   222.46
# | epoch  26 |  1700/ 1844 batches | lr 1.00 | ms/batch 4.027 | loss  5.42 | ppl   224.84
# ...
# | epoch  32 |   900/ 1844 batches | lr 1.00 | ms/batch 3.960 | loss  5.23 | ppl   186.61
# | epoch  32 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.969 | loss  5.17 | ppl   176.35
# | epoch  32 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.919 | loss  5.29 | ppl   199.30
# | epoch  32 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.893 | loss  5.24 | ppl   188.34
# | epoch  32 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.995 | loss  5.17 | ppl   176.21
# | epoch  32 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.946 | loss  5.19 | ppl   180.12
# | epoch  32 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.981 | loss  5.16 | ppl   174.11
# | epoch  32 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.950 | loss  5.21 | ppl   182.76
# | epoch  32 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.919 | loss  5.22 | ppl   185.32
# | epoch  32 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.950 | loss  5.21 | ppl   182.51
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time:  8.91s | valid loss 5.073 | valid ppl   159.65
# -----------------------------------------------------------------------------------------
# | epoch  33 |   100/ 1844 batches | lr 1.00 | ms/batch 4.014 | loss  5.25 | ppl   191.49
# | epoch  33 |   200/ 1844 batches | lr 1.00 | ms/batch 3.943 | loss  5.21 | ppl   183.32
# | epoch  33 |   300/ 1844 batches | lr 1.00 | ms/batch 3.951 | loss  5.19 | ppl   178.65
# | epoch  33 |   400/ 1844 batches | lr 1.00 | ms/batch 3.945 | loss  5.16 | ppl   174.78
# | epoch  33 |   500/ 1844 batches | lr 1.00 | ms/batch 3.933 | loss  5.23 | ppl   187.68
# | epoch  33 |   600/ 1844 batches | lr 1.00 | ms/batch 3.941 | loss  5.17 | ppl   175.11
# | epoch  33 |   700/ 1844 batches | lr 1.00 | ms/batch 4.013 | loss  5.22 | ppl   184.77
# | epoch  33 |   800/ 1844 batches | lr 1.00 | ms/batch 3.959 | loss  5.22 | ppl   184.71
# | epoch  33 |   900/ 1844 batches | lr 1.00 | ms/batch 3.959 | loss  5.19 | ppl   179.52
# | epoch  33 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.951 | loss  5.14 | ppl   170.88
# | epoch  33 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.991 | loss  5.25 | ppl   189.80
# | epoch  33 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.968 | loss  5.22 | ppl   185.33
# | epoch  33 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.938 | loss  5.13 | ppl   169.19
# | epoch  33 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.985 | loss  5.17 | ppl   175.82
# | epoch  33 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.948 | loss  5.13 | ppl   169.58
# | epoch  33 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.981 | loss  5.16 | ppl   175.00
# | epoch  33 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.933 | loss  5.19 | ppl   178.82
# | epoch  33 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.937 | loss  5.17 | ppl   175.22
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time:  8.88s | valid loss 5.037 | valid ppl   154.03
# -----------------------------------------------------------------------------------------
# | epoch  34 |   100/ 1844 batches | lr 1.00 | ms/batch 4.057 | loss  5.21 | ppl   183.48
# | epoch  34 |   200/ 1844 batches | lr 1.00 | ms/batch 3.917 | loss  5.17 | ppl   176.44
# | epoch  34 |   300/ 1844 batches | lr 1.00 | ms/batch 3.957 | loss  5.14 | ppl   170.76
# | epoch  34 |   400/ 1844 batches | lr 1.00 | ms/batch 3.956 | loss  5.14 | ppl   170.45
# | epoch  34 |   500/ 1844 batches | lr 1.00 | ms/batch 3.933 | loss  5.20 | ppl   181.21
# | epoch  34 |   600/ 1844 batches | lr 1.00 | ms/batch 3.970 | loss  5.13 | ppl   168.91
# | epoch  34 |   700/ 1844 batches | lr 1.00 | ms/batch 3.916 | loss  5.20 | ppl   180.85
# | epoch  34 |   800/ 1844 batches | lr 1.00 | ms/batch 3.959 | loss  5.17 | ppl   176.03
# | epoch  34 |   900/ 1844 batches | lr 1.00 | ms/batch 4.057 | loss  5.16 | ppl   174.52
# | epoch  34 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.899 | loss  5.11 | ppl   165.77
# | epoch  34 |  1100/ 1844 batches | lr 1.00 | ms/batch 4.054 | loss  5.22 | ppl   184.97
# | epoch  34 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.900 | loss  5.18 | ppl   178.40
# | epoch  34 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.914 | loss  5.10 | ppl   164.67
# | epoch  34 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.968 | loss  5.13 | ppl   169.12
# | epoch  34 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.946 | loss  5.10 | ppl   163.44
# | epoch  34 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.920 | loss  5.14 | ppl   170.94
# | epoch  34 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.943 | loss  5.15 | ppl   171.88
# | epoch  34 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.942 | loss  5.14 | ppl   170.79
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time:  8.90s | valid loss 5.003 | valid ppl   148.88
# -----------------------------------------------------------------------------------------
# | epoch  35 |   100/ 1844 batches | lr 1.00 | ms/batch 4.030 | loss  5.19 | ppl   179.28
# | epoch  35 |   200/ 1844 batches | lr 1.00 | ms/batch 3.958 | loss  5.13 | ppl   169.21
# | epoch  35 |   300/ 1844 batches | lr 1.00 | ms/batch 3.933 | loss  5.11 | ppl   165.93
# | epoch  35 |   400/ 1844 batches | lr 1.00 | ms/batch 3.964 | loss  5.11 | ppl   165.32
# | epoch  35 |   500/ 1844 batches | lr 1.00 | ms/batch 3.965 | loss  5.17 | ppl   175.25
# | epoch  35 |   600/ 1844 batches | lr 1.00 | ms/batch 3.918 | loss  5.09 | ppl   162.87
# | epoch  35 |   700/ 1844 batches | lr 1.00 | ms/batch 3.894 | loss  5.15 | ppl   173.25
# | epoch  35 |   800/ 1844 batches | lr 1.00 | ms/batch 3.905 | loss  5.14 | ppl   171.54
# | epoch  35 |   900/ 1844 batches | lr 1.00 | ms/batch 3.953 | loss  5.13 | ppl   169.27
# | epoch  35 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.932 | loss  5.06 | ppl   157.92
# | epoch  35 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.939 | loss  5.19 | ppl   180.20
# | epoch  35 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.968 | loss  5.13 | ppl   169.84
# | epoch  35 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.968 | loss  5.07 | ppl   159.24
# | epoch  35 |  1400/ 1844 batches | lr 1.00 | ms/batch 4.018 | loss  5.10 | ppl   163.53
# | epoch  35 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.966 | loss  5.07 | ppl   159.16
# | epoch  35 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.928 | loss  5.11 | ppl   165.88
# | epoch  35 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.982 | loss  5.13 | ppl   169.12
# | epoch  35 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.947 | loss  5.11 | ppl   165.85
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time:  8.88s | valid loss 4.967 | valid ppl   143.67
# -----------------------------------------------------------------------------------------
# | epoch  36 |   100/ 1844 batches | lr 1.00 | ms/batch 4.019 | loss  5.15 | ppl   172.77
# | epoch  36 |   200/ 1844 batches | lr 1.00 | ms/batch 3.956 | loss  5.10 | ppl   164.34
# | epoch  36 |   300/ 1844 batches | lr 1.00 | ms/batch 3.949 | loss  5.09 | ppl   162.61
# | epoch  36 |   400/ 1844 batches | lr 1.00 | ms/batch 3.924 | loss  5.08 | ppl   160.58
# | epoch  36 |   500/ 1844 batches | lr 1.00 | ms/batch 3.942 | loss  5.14 | ppl   169.96
# | epoch  36 |   600/ 1844 batches | lr 1.00 | ms/batch 3.900 | loss  5.07 | ppl   159.09
# | epoch  36 |   700/ 1844 batches | lr 1.00 | ms/batch 3.952 | loss  5.12 | ppl   167.68
# | epoch  36 |   800/ 1844 batches | lr 1.00 | ms/batch 3.963 | loss  5.12 | ppl   167.20
# | epoch  36 |   900/ 1844 batches | lr 1.00 | ms/batch 3.915 | loss  5.10 | ppl   164.13
# | epoch  36 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.976 | loss  5.04 | ppl   154.16
# | epoch  36 |  1100/ 1844 batches | lr 1.00 | ms/batch 4.063 | loss  5.16 | ppl   174.74
# | epoch  36 |  1200/ 1844 batches | lr 1.00 | ms/batch 4.004 | loss  5.12 | ppl   167.88
# | epoch  36 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.929 | loss  5.03 | ppl   153.48
# | epoch  36 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.941 | loss  5.07 | ppl   159.64
# | epoch  36 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.968 | loss  5.03 | ppl   153.10
# | epoch  36 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.912 | loss  5.08 | ppl   160.99
# | epoch  36 |  1700/ 1844 batches | lr 1.00 | ms/batch 4.027 | loss  5.09 | ppl   162.68
# | epoch  36 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.912 | loss  5.08 | ppl   160.33
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time:  8.89s | valid loss 4.935 | valid ppl   139.07
# -----------------------------------------------------------------------------------------
# | epoch  37 |   100/ 1844 batches | lr 1.00 | ms/batch 4.149 | loss  5.13 | ppl   169.02
# | epoch  37 |   200/ 1844 batches | lr 1.00 | ms/batch 3.901 | loss  5.07 | ppl   159.69
# | epoch  37 |   300/ 1844 batches | lr 1.00 | ms/batch 3.980 | loss  5.06 | ppl   157.70
# | epoch  37 |   400/ 1844 batches | lr 1.00 | ms/batch 3.918 | loss  5.03 | ppl   153.23
# | epoch  37 |   500/ 1844 batches | lr 1.00 | ms/batch 3.940 | loss  5.09 | ppl   161.64
# | epoch  37 |   600/ 1844 batches | lr 1.00 | ms/batch 3.900 | loss  5.03 | ppl   152.78
# | epoch  37 |   700/ 1844 batches | lr 1.00 | ms/batch 3.914 | loss  5.09 | ppl   162.23
# | epoch  37 |   800/ 1844 batches | lr 1.00 | ms/batch 4.008 | loss  5.08 | ppl   161.36
# | epoch  37 |   900/ 1844 batches | lr 1.00 | ms/batch 3.900 | loss  5.07 | ppl   158.98
# | epoch  37 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.994 | loss  5.00 | ppl   148.60
# | epoch  37 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.932 | loss  5.11 | ppl   165.42
# | epoch  37 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.955 | loss  5.07 | ppl   159.91
# | epoch  37 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.978 | loss  5.00 | ppl   149.10
# | epoch  37 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.903 | loss  5.03 | ppl   153.26
# | epoch  37 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.933 | loss  4.99 | ppl   147.31
# | epoch  37 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.922 | loss  5.05 | ppl   156.01
# | epoch  37 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.987 | loss  5.05 | ppl   156.65
# | epoch  37 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.940 | loss  5.05 | ppl   155.83
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time:  8.89s | valid loss 4.894 | valid ppl   133.50
# -----------------------------------------------------------------------------------------
# | epoch  38 |   100/ 1844 batches | lr 1.00 | ms/batch 4.061 | loss  5.08 | ppl   160.76
# | epoch  38 |   200/ 1844 batches | lr 1.00 | ms/batch 3.902 | loss  5.04 | ppl   154.43
# | epoch  38 |   300/ 1844 batches | lr 1.00 | ms/batch 3.973 | loss  5.02 | ppl   151.78
# | epoch  38 |   400/ 1844 batches | lr 1.00 | ms/batch 3.979 | loss  5.02 | ppl   150.69
# | epoch  38 |   500/ 1844 batches | lr 1.00 | ms/batch 4.005 | loss  5.06 | ppl   156.90
# | epoch  38 |   600/ 1844 batches | lr 1.00 | ms/batch 3.936 | loss  5.00 | ppl   148.17
# | epoch  38 |   700/ 1844 batches | lr 1.00 | ms/batch 3.946 | loss  5.05 | ppl   155.84
# | epoch  38 |   800/ 1844 batches | lr 1.00 | ms/batch 3.950 | loss  5.05 | ppl   155.69
# | epoch  38 |   900/ 1844 batches | lr 1.00 | ms/batch 3.914 | loss  5.03 | ppl   153.22
# | epoch  38 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.929 | loss  4.97 | ppl   144.60
# | epoch  38 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.975 | loss  5.09 | ppl   161.76
# | epoch  38 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.951 | loss  5.06 | ppl   157.97
# | epoch  38 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.919 | loss  4.97 | ppl   144.00
# | epoch  38 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.951 | loss  5.00 | ppl   148.35
# | epoch  38 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.954 | loss  4.96 | ppl   143.00
# | epoch  38 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.938 | loss  5.02 | ppl   150.77
# | epoch  38 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.947 | loss  5.03 | ppl   153.23
# | epoch  38 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.919 | loss  4.99 | ppl   147.60
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time:  8.86s | valid loss 4.859 | valid ppl   128.86
# -----------------------------------------------------------------------------------------
# | epoch  39 |   100/ 1844 batches | lr 1.00 | ms/batch 4.059 | loss  5.06 | ppl   158.24
# | epoch  39 |   200/ 1844 batches | lr 1.00 | ms/batch 4.029 | loss  5.01 | ppl   149.64
# | epoch  39 |   300/ 1844 batches | lr 1.00 | ms/batch 3.945 | loss  4.99 | ppl   147.21
# | epoch  39 |   400/ 1844 batches | lr 1.00 | ms/batch 3.918 | loss  4.97 | ppl   144.55
# | epoch  39 |   500/ 1844 batches | lr 1.00 | ms/batch 3.914 | loss  5.02 | ppl   151.72
# | epoch  39 |   600/ 1844 batches | lr 1.00 | ms/batch 3.970 | loss  4.96 | ppl   142.56
# | epoch  39 |   700/ 1844 batches | lr 1.00 | ms/batch 3.981 | loss  5.03 | ppl   152.29
# | epoch  39 |   800/ 1844 batches | lr 1.00 | ms/batch 3.923 | loss  5.01 | ppl   149.90
# | epoch  39 |   900/ 1844 batches | lr 1.00 | ms/batch 3.934 | loss  5.01 | ppl   149.56
# | epoch  39 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.930 | loss  4.94 | ppl   140.27
# | epoch  39 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.936 | loss  5.05 | ppl   155.88
# | epoch  39 |  1200/ 1844 batches | lr 1.00 | ms/batch 3.932 | loss  5.01 | ppl   150.17
# | epoch  39 |  1300/ 1844 batches | lr 1.00 | ms/batch 3.969 | loss  4.94 | ppl   139.45
# | epoch  39 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.973 | loss  4.97 | ppl   144.14
# | epoch  39 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.916 | loss  4.93 | ppl   137.98
# | epoch  39 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.922 | loss  4.99 | ppl   147.32
# | epoch  39 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.990 | loss  4.99 | ppl   147.28
# | epoch  39 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.959 | loss  4.97 | ppl   144.28
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time:  8.88s | valid loss 4.821 | valid ppl   124.14
# -----------------------------------------------------------------------------------------
# | epoch  40 |   100/ 1844 batches | lr 1.00 | ms/batch 4.015 | loss  5.02 | ppl   150.93
# | epoch  40 |   200/ 1844 batches | lr 1.00 | ms/batch 3.953 | loss  4.97 | ppl   143.40
# | epoch  40 |   300/ 1844 batches | lr 1.00 | ms/batch 3.970 | loss  4.96 | ppl   142.36
# | epoch  40 |   400/ 1844 batches | lr 1.00 | ms/batch 3.960 | loss  4.94 | ppl   139.73
# | epoch  40 |   500/ 1844 batches | lr 1.00 | ms/batch 4.018 | loss  4.99 | ppl   146.90
# | epoch  40 |   600/ 1844 batches | lr 1.00 | ms/batch 3.961 | loss  4.94 | ppl   139.47
# | epoch  40 |   700/ 1844 batches | lr 1.00 | ms/batch 3.949 | loss  4.98 | ppl   145.82
# | epoch  40 |   800/ 1844 batches | lr 1.00 | ms/batch 3.953 | loss  4.99 | ppl   146.37
# | epoch  40 |   900/ 1844 batches | lr 1.00 | ms/batch 3.924 | loss  4.97 | ppl   143.54
# | epoch  40 |  1000/ 1844 batches | lr 1.00 | ms/batch 3.965 | loss  4.90 | ppl   134.63
# | epoch  40 |  1100/ 1844 batches | lr 1.00 | ms/batch 3.997 | loss  5.02 | ppl   151.25
# | epoch  40 |  1200/ 1844 batches | lr 1.00 | ms/batch 4.047 | loss  4.99 | ppl   146.78
# | epoch  40 |  1300/ 1844 batches | lr 1.00 | ms/batch 4.006 | loss  4.90 | ppl   134.59
# | epoch  40 |  1400/ 1844 batches | lr 1.00 | ms/batch 3.914 | loss  4.94 | ppl   139.37
# | epoch  40 |  1500/ 1844 batches | lr 1.00 | ms/batch 3.970 | loss  4.90 | ppl   133.64
# | epoch  40 |  1600/ 1844 batches | lr 1.00 | ms/batch 3.944 | loss  4.95 | ppl   140.73
# | epoch  40 |  1700/ 1844 batches | lr 1.00 | ms/batch 3.926 | loss  4.96 | ppl   142.59
# | epoch  40 |  1800/ 1844 batches | lr 1.00 | ms/batch 3.999 | loss  4.93 | ppl   139.04
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time:  8.90s | valid loss 4.788 | valid ppl   120.04
# -----------------------------------------------------------------------------------------

# %% [markdown]
# ### Проверка качества, экспорт в ONNX

# %%
# Загрузка лучшей модели.
with open(savefile, 'rb') as f:
    model = torch.load(f)
    # после загрузки параметры RNN находятся не в одном сегменте памяти
    # для помещения в один участок и ускорения прямого прохода
    # В настоящее время, только рекуррентная модель поддерживает flatten_parameters.
    if model_type in ['RNN_TANH', 'RNN_RELU', 'LSTM', 'GRU']:
        model.rnn.flatten_parameters()

# Финальная проверка качества
test_loss = evaluate(y)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.3f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)

onnx_export = '%s_next_token.onnx'%(model_type)
if len(onnx_export) > 0:
    # Экспортирование модели в формат ONNX
    export_onnx(onnx_export, batch_size=1, seq_len=WINDOW_SIZE)
# Out:
# =========================================================================================
# | End of training | test loss  4.79 | test ppl  120.039
# =========================================================================================
# The model is also exported in ONNX format at /content/Conv_next_token.onnx.

# %% [markdown]
# ### Получение эмбеддингов, проекция на 2D

# %%
#from sklearn.decomposition import PCA
embeddings = list(model.encoder.parameters())[0].detach().cpu().numpy()

embeddings = UMAP(n_components=2, random_state=2).fit_transform(embeddings)

# %% [markdown]
# ### Визуализация пространства эмбеддингов

# %%
# Визуализация обученных эмбеддингов
fig, ax = plt.subplots(figsize=(20, 20))
ax.scatter(embeddings[:, 0], embeddings[:, 1], s=0.5, alpha=0.4)

# берём 300 наиболее частых
whitelist = frozenset(corpus_df.token_ids.value_counts().index[:300].values)
for i, txt in enumerate(embeddings):
    token_id = ids2token_ids[i]
    if token_id not in whitelist:
        continue
    ax.annotate(vocabs[token_id][0],
                (embeddings[i][0], embeddings[i][1]))
plt.savefig('vecs_%s.svg'%model_type)

# %% [markdown]
# ## Обучение рекуррентной модели LSTM

# %%
model = RNNModel('LSTM', np.unique(y).size, 50, 256, 2, 0.1, False).to(device)
criterion = nn.NLLLoss()
model
# Out:
# RNNModel(
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(8337, 50)
#   (rnn): LSTM(50, 256, num_layers=2, dropout=0.1)
#   (decoder): Linear(in_features=256, out_features=8337, bias=True)
# )

# %%
model_type = 'LSTM'
lr=10
bptt = 1024
eval_batch_size = bptt
clip = 0.25
log_interval = 10
dry_run = False

# %% [markdown]
# ### Вывод числа параметров

# %%
print(*[(k, p.view(-1).size()[0]) for k, p in model.named_parameters()],
      sep='\n')
print('Всего: {:,}'.format(sum(p.view(-1).size()[0] for k, p in model.named_parameters())))
# Out:
# ('encoder.weight', 416850)
# ('rnn.weight_ih_l0', 51200)
# ('rnn.weight_hh_l0', 262144)
# ('rnn.bias_ih_l0', 1024)
# ('rnn.bias_hh_l0', 1024)
# ('rnn.weight_ih_l1', 262144)
# ('rnn.weight_hh_l1', 262144)
# ('rnn.bias_ih_l1', 1024)
# ('rnn.bias_hh_l1', 1024)
# ('decoder.weight', 2134272)
# ('decoder.bias', 8337)
# Всего: 3,401,187

# %% [markdown]
# ### Замер времени прохождения по всему корпусу

# %%
# %%time
evaluate(y)
# Out:
# CPU times: user 6.53 s, sys: 22 ms, total: 6.55 s
# Wall time: 6.56 s
# 9.032107811873614

# %% [markdown]
# ### Обучение модели

# %%
# Loop over epochs.
epochs = 30
best_val_loss = None
savefile = '%s_next_token.pt'%model_type

# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, epochs+1):
        epoch_start_time = time.time()
        train()
        val_loss = evaluate(y)
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.3f} | '
                'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                           val_loss, math.exp(val_loss)))
        print('-' * 89)
        # Save the model if the validation loss is the best we've seen so far.
        if not best_val_loss or val_loss < best_val_loss:
            with open(savefile, 'wb') as f:
                torch.save(model, f)
            best_val_loss = val_loss
        else:
            # Anneal the learning rate if no improvement has been seen in the validation dataset.
            lr /= 2.0
except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 23.57s | valid loss 6.524 | valid ppl   681.17
# -----------------------------------------------------------------------------------------
# | epoch   4 |    10/  115 batches | lr 10.00 | ms/batch 160.969 | loss  7.16 | ppl  1293.32
# | epoch   4 |    20/  115 batches | lr 10.00 | ms/batch 146.117 | loss  6.48 | ppl   651.91
# | epoch   4 |    30/  115 batches | lr 10.00 | ms/batch 146.283 | loss  6.52 | ppl   679.76
# | epoch   4 |    40/  115 batches | lr 10.00 | ms/batch 145.752 | loss  6.44 | ppl   628.03
# | epoch   4 |    50/  115 batches | lr 10.00 | ms/batch 146.188 | loss  6.48 | ppl   649.77
# | epoch   4 |    60/  115 batches | lr 10.00 | ms/batch 146.640 | loss  6.41 | ppl   605.81
# | epoch   4 |    70/  115 batches | lr 10.00 | ms/batch 146.589 | loss  6.47 | ppl   643.42
# | epoch   4 |    80/  115 batches | lr 10.00 | ms/batch 146.648 | loss  6.39 | ppl   593.83
# | epoch   4 |    90/  115 batches | lr 10.00 | ms/batch 146.645 | loss  6.37 | ppl   585.22
# | epoch   4 |   100/  115 batches | lr 10.00 | ms/batch 146.545 | loss  6.36 | ppl   578.88
# | epoch   4 |   110/  115 batches | lr 10.00 | ms/batch 146.941 | loss  6.34 | ppl   569.51
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 23.50s | valid loss 6.354 | valid ppl   574.55
# -----------------------------------------------------------------------------------------
# | epoch   5 |    10/  115 batches | lr 10.00 | ms/batch 162.194 | loss  6.98 | ppl  1074.60
# | epoch   5 |    20/  115 batches | lr 10.00 | ms/batch 147.678 | loss  6.32 | ppl   553.48
# | epoch   5 |    30/  115 batches | lr 10.00 | ms/batch 147.985 | loss  6.32 | ppl   557.46
# | epoch   5 |    40/  115 batches | lr 10.00 | ms/batch 147.503 | loss  6.32 | ppl   554.63
# | epoch   5 |    50/  115 batches | lr 10.00 | ms/batch 147.930 | loss  6.31 | ppl   547.54
# | epoch   5 |    60/  115 batches | lr 10.00 | ms/batch 148.017 | loss  6.28 | ppl   535.19
# | epoch   5 |    70/  115 batches | lr 10.00 | ms/batch 148.058 | loss  6.32 | ppl   553.36
# | epoch   5 |    80/  115 batches | lr 10.00 | ms/batch 147.823 | loss  6.27 | ppl   528.64
# | epoch   5 |    90/  115 batches | lr 10.00 | ms/batch 148.126 | loss  6.23 | ppl   507.80
# | epoch   5 |   100/  115 batches | lr 10.00 | ms/batch 147.818 | loss  6.25 | ppl   517.10
# | epoch   5 |   110/  115 batches | lr 10.00 | ms/batch 147.812 | loss  6.26 | ppl   520.77
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 23.73s | valid loss 6.228 | valid ppl   506.53
# -----------------------------------------------------------------------------------------
# | epoch   6 |    10/  115 batches | lr 10.00 | ms/batch 163.994 | loss  6.83 | ppl   929.48
# | epoch   6 |    20/  115 batches | lr 10.00 | ms/batch 148.366 | loss  6.21 | ppl   495.65
# | epoch   6 |    30/  115 batches | lr 10.00 | ms/batch 148.721 | loss  6.22 | ppl   504.89
# | epoch   6 |    40/  115 batches | lr 10.00 | ms/batch 148.466 | loss  6.21 | ppl   500.19
# | epoch   6 |    50/  115 batches | lr 10.00 | ms/batch 148.069 | loss  6.24 | ppl   510.42
# | epoch   6 |    60/  115 batches | lr 10.00 | ms/batch 149.179 | loss  6.17 | ppl   479.77
# | epoch   6 |    70/  115 batches | lr 10.00 | ms/batch 148.343 | loss  6.21 | ppl   499.80
# | epoch   6 |    80/  115 batches | lr 10.00 | ms/batch 148.545 | loss  6.18 | ppl   484.70
# | epoch   6 |    90/  115 batches | lr 10.00 | ms/batch 148.952 | loss  6.16 | ppl   471.57
# | epoch   6 |   100/  115 batches | lr 10.00 | ms/batch 148.687 | loss  6.16 | ppl   471.96
# | epoch   6 |   110/  115 batches | lr 10.00 | ms/batch 148.635 | loss  6.16 | ppl   473.60
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 23.81s | valid loss 6.130 | valid ppl   459.35
# -----------------------------------------------------------------------------------------
# | epoch   7 |    10/  115 batches | lr 10.00 | ms/batch 163.677 | loss  6.76 | ppl   864.46
# | epoch   7 |    20/  115 batches | lr 10.00 | ms/batch 147.830 | loss  6.12 | ppl   453.97
# | epoch   7 |    30/  115 batches | lr 10.00 | ms/batch 147.420 | loss  6.16 | ppl   471.79
# | epoch   7 |    40/  115 batches | lr 10.00 | ms/batch 148.410 | loss  6.15 | ppl   467.43
# | epoch   7 |    50/  115 batches | lr 10.00 | ms/batch 147.880 | loss  6.12 | ppl   455.56
# | epoch   7 |    60/  115 batches | lr 10.00 | ms/batch 148.016 | loss  6.10 | ppl   446.61
# | epoch   7 |    70/  115 batches | lr 10.00 | ms/batch 148.332 | loss  6.15 | ppl   466.99
# | epoch   7 |    80/  115 batches | lr 10.00 | ms/batch 147.887 | loss  6.10 | ppl   444.15
# | epoch   7 |    90/  115 batches | lr 10.00 | ms/batch 147.888 | loss  6.09 | ppl   439.66
# | epoch   7 |   100/  115 batches | lr 10.00 | ms/batch 147.544 | loss  6.08 | ppl   438.40
# | epoch   7 |   110/  115 batches | lr 10.00 | ms/batch 147.640 | loss  6.09 | ppl   442.00
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 23.71s | valid loss 6.028 | valid ppl   414.77
# -----------------------------------------------------------------------------------------
# | epoch   8 |    10/  115 batches | lr 10.00 | ms/batch 162.479 | loss  6.67 | ppl   788.26
# | epoch   8 |    20/  115 batches | lr 10.00 | ms/batch 147.704 | loss  6.05 | ppl   425.15
# | epoch   8 |    30/  115 batches | lr 10.00 | ms/batch 147.629 | loss  6.05 | ppl   425.35
# | epoch   8 |    40/  115 batches | lr 10.00 | ms/batch 147.450 | loss  6.05 | ppl   423.10
# | epoch   8 |    50/  115 batches | lr 10.00 | ms/batch 147.394 | loss  6.07 | ppl   432.69
# | epoch   8 |    60/  115 batches | lr 10.00 | ms/batch 147.668 | loss  6.01 | ppl   408.27
# | epoch   8 |    70/  115 batches | lr 10.00 | ms/batch 147.584 | loss  6.07 | ppl   432.22
# | epoch  30 |    80/  115 batches | lr 10.00 | ms/batch 148.542 | loss  4.23 | ppl    68.86
# | epoch  30 |    90/  115 batches | lr 10.00 | ms/batch 149.075 | loss  4.22 | ppl    68.09
# | epoch  30 |   100/  115 batches | lr 10.00 | ms/batch 148.459 | loss  4.21 | ppl    67.26
# | epoch  30 |   110/  115 batches | lr 10.00 | ms/batch 148.515 | loss  4.22 | ppl    67.76
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 23.85s | valid loss 4.284 | valid ppl    72.54
# -----------------------------------------------------------------------------------------

# %% [markdown]
# ### Проверка качества, экспорт в ONNX

# %%
# Загрузка лучшей модели.
with open(savefile, 'rb') as f:
    model = torch.load(f)
    # после загрузки параметры RNN находятся не в одном сегменте памяти
    # для помещения в один участок и ускорения прямого прохода
    # В настоящее время, только рекуррентная модель поддерживает flatten_parameters.
    if model_type in ['RNN_TANH', 'RNN_RELU', 'LSTM', 'GRU']:
        model.rnn.flatten_parameters()

# Финальная проверка качества
test_loss = evaluate(y)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.3f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)

onnx_export = '%s_next_token.onnx'%(model_type)
if len(onnx_export) > 0:
    # Экспортирование модели в формат ONNX
    export_onnx(onnx_export, batch_size=1, seq_len=WINDOW_SIZE)
# Out:
# =========================================================================================
# | End of training | test loss  4.28 | test ppl   72.540
# =========================================================================================
# The model is also exported in ONNX format at /content/LSTM_next_token.onnx.
# /usr/local/lib/python3.7/dist-packages/torch/onnx/symbolic_opset9.py:2192: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   "or define the initial states (h0/c0) as inputs of the model. ")

# %% [markdown]
# ### Получение эмбеддингов, проекция на 2D

# %%
#from sklearn.decomposition import PCA
embeddings = list(model.encoder.parameters())[0].detach().cpu().numpy()

embeddings = UMAP(n_components=2, random_state=2).fit_transform(embeddings)

# %% [markdown]
# ### Визуализация пространства эмбеддингов

# %%
# Визуализация обученных эмбеддингов
fig, ax = plt.subplots(figsize=(20, 20))
ax.scatter(embeddings[:, 0], embeddings[:, 1], s=0.5, alpha=0.4)

# берём 300 наиболее частых
whitelist = frozenset(corpus_df.token_ids.value_counts().index[:300].values)
for i, txt in enumerate(embeddings):
    token_id = ids2token_ids[i]
    if token_id not in whitelist:
        continue
    ax.annotate(vocabs[token_id][0],
                (embeddings[i][0], embeddings[i][1]))
plt.savefig('vecs_%s.svg'%model_type)

# %% [markdown]
# ## Обучение модели self-attention

# %%
model = TransformerModel(np.unique(y).size, 128+32, 4, 192, 2, 0.1).to(device)
# ntoken, ninp, nhead, nhid, nlayers, dropout
criterion = nn.NLLLoss()
model
# Out:
# TransformerModel(
#   (pos_encoder): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=160, out_features=160, bias=True)
#         )
#         (linear1): Linear(in_features=160, out_features=192, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=192, out_features=160, bias=True)
#         (norm1): LayerNorm((160,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((160,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=160, out_features=160, bias=True)
#         )
#         (linear1): Linear(in_features=160, out_features=192, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=192, out_features=160, bias=True)
#         (norm1): LayerNorm((160,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((160,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (encoder): Embedding(8337, 160)
#   (decoder): Linear(in_features=160, out_features=8337, bias=True)
# )

# %%
model_type = 'Transformer'
lr = 2.0
bptt = 64
eval_batch_size = bptt
clip = 0.25
log_interval = 100
dry_run = False

# %% [markdown]
# ### Вывод числа параметров

# %%
print(*[(k, p.view(-1).size()[0]) for k, p in model.named_parameters()],
      sep='\n')
print('Всего: {:,}'.format(sum(p.view(-1).size()[0] for k, p in model.named_parameters())))
# Out:
# ('transformer_encoder.layers.0.self_attn.in_proj_weight', 76800)
# ('transformer_encoder.layers.0.self_attn.in_proj_bias', 480)
# ('transformer_encoder.layers.0.self_attn.out_proj.weight', 25600)
# ('transformer_encoder.layers.0.self_attn.out_proj.bias', 160)
# ('transformer_encoder.layers.0.linear1.weight', 30720)
# ('transformer_encoder.layers.0.linear1.bias', 192)
# ('transformer_encoder.layers.0.linear2.weight', 30720)
# ('transformer_encoder.layers.0.linear2.bias', 160)
# ('transformer_encoder.layers.0.norm1.weight', 160)
# ('transformer_encoder.layers.0.norm1.bias', 160)
# ('transformer_encoder.layers.0.norm2.weight', 160)
# ('transformer_encoder.layers.0.norm2.bias', 160)
# ('transformer_encoder.layers.1.self_attn.in_proj_weight', 76800)
# ('transformer_encoder.layers.1.self_attn.in_proj_bias', 480)
# ('transformer_encoder.layers.1.self_attn.out_proj.weight', 25600)
# ('transformer_encoder.layers.1.self_attn.out_proj.bias', 160)
# ('transformer_encoder.layers.1.linear1.weight', 30720)
# ('transformer_encoder.layers.1.linear1.bias', 192)
# ('transformer_encoder.layers.1.linear2.weight', 30720)
# ('transformer_encoder.layers.1.linear2.bias', 160)
# ('transformer_encoder.layers.1.norm1.weight', 160)
# ('transformer_encoder.layers.1.norm1.bias', 160)
# ('transformer_encoder.layers.1.norm2.weight', 160)
# ('transformer_encoder.layers.1.norm2.bias', 160)
# ('encoder.weight', 1333920)
# ('decoder.weight', 1333920)
# ('decoder.bias', 8337)
# Всего: 3,007,121

# %% [markdown]
# ### Замер времени прохождения по всему корпусу

# %%
# %%time
evaluate(y)
# Out:
# CPU times: user 5.17 s, sys: 7.31 ms, total: 5.18 s
# Wall time: 5.15 s
# 9.289510623021926

# %% [markdown]
# ### Обучение модели

# %%
# Loop over epochs.
epochs = 40
best_val_loss = None
savefile = '%s_next_token.pt'%model_type

patience_max = 2
patience = 0
# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, epochs+1):
        epoch_start_time = time.time()
        train()
        val_loss = evaluate(y)
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.3f} | '
                'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                           val_loss, math.exp(val_loss)))
        print('-' * 89)
        # Save the model if the validation loss is the best we've seen so far.
        if not best_val_loss or val_loss < best_val_loss:
            with open(savefile, 'wb') as f:
                torch.save(model, f)
            best_val_loss = val_loss
            patience = 0
        else:
            patience += 1
            if patience < patience_max: continue 
            with open(savefile, 'rb') as f:
                model = torch.load(f)
            # Anneal the learning rate if no improvement has been seen in the validation dataset.
            lr /= 2.0
            patience = 0
except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')
# Out:
# | epoch   1 |   100/ 1844 batches | lr 2.00 | ms/batch 8.288 | loss  7.41 | ppl  1645.76
# | epoch   1 |   200/ 1844 batches | lr 2.00 | ms/batch 8.167 | loss  6.88 | ppl   973.68
# | epoch   1 |   300/ 1844 batches | lr 2.00 | ms/batch 8.074 | loss  6.70 | ppl   815.84
# | epoch   1 |   400/ 1844 batches | lr 2.00 | ms/batch 8.090 | loss  6.58 | ppl   722.52
# | epoch   1 |   500/ 1844 batches | lr 2.00 | ms/batch 8.161 | loss  6.50 | ppl   667.99
# | epoch   1 |   600/ 1844 batches | lr 2.00 | ms/batch 8.090 | loss  6.39 | ppl   594.66
# | epoch   1 |   700/ 1844 batches | lr 2.00 | ms/batch 8.091 | loss  6.41 | ppl   609.06
# | epoch   1 |   800/ 1844 batches | lr 2.00 | ms/batch 8.137 | loss  6.31 | ppl   551.10
# | epoch   1 |   900/ 1844 batches | lr 2.00 | ms/batch 8.073 | loss  6.25 | ppl   518.79
# | epoch   1 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.181 | loss  6.18 | ppl   482.91
# | epoch   1 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.157 | loss  6.25 | ppl   516.14
# | epoch   1 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.230 | loss  6.14 | ppl   466.37
# | epoch   1 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.207 | loss  6.05 | ppl   424.68
# | epoch   1 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.172 | loss  6.03 | ppl   417.18
# | epoch   1 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.201 | loss  5.97 | ppl   392.72
# | epoch   1 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.198 | loss  6.02 | ppl   413.19
# | epoch   1 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.116 | loss  6.01 | ppl   408.44
# | epoch   1 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.258 | loss  5.99 | ppl   399.19
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 20.18s | valid loss 5.646 | valid ppl   283.03
# -----------------------------------------------------------------------------------------
# | epoch   2 |   100/ 1844 batches | lr 2.00 | ms/batch 8.321 | loss  5.90 | ppl   365.93
# | epoch   2 |   200/ 1844 batches | lr 2.00 | ms/batch 8.252 | loss  5.80 | ppl   331.62
# | epoch   2 |   300/ 1844 batches | lr 2.00 | ms/batch 8.231 | loss  5.75 | ppl   313.10
# | epoch   2 |   400/ 1844 batches | lr 2.00 | ms/batch 8.251 | loss  5.70 | ppl   298.76
# | epoch   2 |   500/ 1844 batches | lr 2.00 | ms/batch 8.224 | loss  5.69 | ppl   295.50
# | epoch   2 |   600/ 1844 batches | lr 2.00 | ms/batch 8.308 | loss  5.65 | ppl   284.04
# | epoch   2 |   700/ 1844 batches | lr 2.00 | ms/batch 8.226 | loss  5.69 | ppl   294.64
# | epoch   2 |   800/ 1844 batches | lr 2.00 | ms/batch 8.226 | loss  5.64 | ppl   282.16
# | epoch   2 |   900/ 1844 batches | lr 2.00 | ms/batch 8.190 | loss  5.61 | ppl   274.44
# | epoch   2 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.283 | loss  5.56 | ppl   260.59
# | epoch   2 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.162 | loss  5.65 | ppl   283.40
# | epoch   2 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.234 | loss  5.56 | ppl   260.24
# | epoch   2 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.327 | loss  5.51 | ppl   246.09
# | epoch   2 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.221 | loss  5.51 | ppl   246.39
# | epoch   2 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.204 | loss  5.46 | ppl   235.22
# | epoch   2 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.137 | loss  5.52 | ppl   248.96
# | epoch   2 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.224 | loss  5.51 | ppl   247.06
# | epoch   2 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.199 | loss  5.52 | ppl   249.15
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 20.30s | valid loss 5.152 | valid ppl   172.84
# -----------------------------------------------------------------------------------------
# | epoch   3 |   100/ 1844 batches | lr 2.00 | ms/batch 8.449 | loss  5.45 | ppl   231.91
# | epoch   3 |   200/ 1844 batches | lr 2.00 | ms/batch 8.190 | loss  5.36 | ppl   213.09
# | epoch   3 |   300/ 1844 batches | lr 2.00 | ms/batch 8.121 | loss  5.31 | ppl   202.50
# | epoch   3 |   400/ 1844 batches | lr 2.00 | ms/batch 8.170 | loss  5.27 | ppl   194.86
# | epoch   3 |   500/ 1844 batches | lr 2.00 | ms/batch 8.093 | loss  5.28 | ppl   196.35
# | epoch   3 |   600/ 1844 batches | lr 2.00 | ms/batch 8.324 | loss  5.25 | ppl   190.67
# | epoch   3 |   700/ 1844 batches | lr 2.00 | ms/batch 8.149 | loss  5.27 | ppl   193.97
# | epoch   3 |   800/ 1844 batches | lr 2.00 | ms/batch 8.113 | loss  5.24 | ppl   188.11
# | epoch   3 |   900/ 1844 batches | lr 2.00 | ms/batch 8.123 | loss  5.22 | ppl   184.30
# | epoch   3 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.138 | loss  5.17 | ppl   176.58
# | epoch   3 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.178 | loss  5.26 | ppl   192.04
# | epoch   3 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.091 | loss  5.19 | ppl   178.78
# | epoch   3 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.146 | loss  5.14 | ppl   170.64
# | epoch   3 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.217 | loss  5.15 | ppl   171.71
# | epoch   3 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.133 | loss  5.10 | ppl   164.24
# | epoch   3 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.127 | loss  5.17 | ppl   175.68
# | epoch   3 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.149 | loss  5.17 | ppl   175.55
# | epoch   3 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.096 | loss  5.18 | ppl   177.24
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 20.16s | valid loss 4.798 | valid ppl   121.29
# -----------------------------------------------------------------------------------------
# | epoch   4 |   100/ 1844 batches | lr 2.00 | ms/batch 8.311 | loss  5.12 | ppl   167.32
# | epoch   4 |   200/ 1844 batches | lr 2.00 | ms/batch 8.209 | loss  5.05 | ppl   155.35
# | epoch   4 |   300/ 1844 batches | lr 2.00 | ms/batch 8.071 | loss  4.97 | ppl   143.87
# | epoch   4 |   400/ 1844 batches | lr 2.00 | ms/batch 8.043 | loss  4.96 | ppl   142.35
# | epoch   4 |   500/ 1844 batches | lr 2.00 | ms/batch 8.051 | loss  4.96 | ppl   142.86
# | epoch   4 |   600/ 1844 batches | lr 2.00 | ms/batch 8.071 | loss  4.95 | ppl   140.78
# | epoch   4 |   700/ 1844 batches | lr 2.00 | ms/batch 8.097 | loss  4.95 | ppl   141.04
# | epoch   4 |   800/ 1844 batches | lr 2.00 | ms/batch 8.036 | loss  4.92 | ppl   137.33
# | epoch   4 |   900/ 1844 batches | lr 2.00 | ms/batch 8.082 | loss  4.92 | ppl   137.61
# | epoch   4 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.070 | loss  4.88 | ppl   132.22
# | epoch   4 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.110 | loss  4.94 | ppl   139.92
# | epoch   4 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.081 | loss  4.89 | ppl   132.78
# | epoch   4 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.049 | loss  4.85 | ppl   128.34
# | epoch   4 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.039 | loss  4.87 | ppl   130.78
# | epoch   4 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.277 | loss  4.82 | ppl   123.66
# | epoch   4 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.128 | loss  4.88 | ppl   131.79
# | epoch   4 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.129 | loss  4.87 | ppl   130.57
# | epoch   4 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.200 | loss  4.90 | ppl   134.72
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 20.10s | valid loss 4.505 | valid ppl    90.49
# -----------------------------------------------------------------------------------------
# | epoch   5 |   100/ 1844 batches | lr 2.00 | ms/batch 8.208 | loss  4.85 | ppl   127.69
# | epoch   5 |   200/ 1844 batches | lr 2.00 | ms/batch 8.077 | loss  4.78 | ppl   119.00
# | epoch   5 |   300/ 1844 batches | lr 2.00 | ms/batch 8.075 | loss  4.69 | ppl   108.44
# | epoch   5 |   400/ 1844 batches | lr 2.00 | ms/batch 8.089 | loss  4.69 | ppl   109.29
# | epoch   5 |   500/ 1844 batches | lr 2.00 | ms/batch 8.078 | loss  4.70 | ppl   109.45
# | epoch   5 |   600/ 1844 batches | lr 2.00 | ms/batch 8.093 | loss  4.68 | ppl   107.40
# | epoch   5 |   700/ 1844 batches | lr 2.00 | ms/batch 8.098 | loss  4.68 | ppl   108.27
# | epoch   5 |   800/ 1844 batches | lr 2.00 | ms/batch 8.053 | loss  4.65 | ppl   104.77
# | epoch   5 |   900/ 1844 batches | lr 2.00 | ms/batch 8.121 | loss  4.67 | ppl   106.57
# | epoch   5 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.115 | loss  4.63 | ppl   102.24
# | epoch   5 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.121 | loss  4.69 | ppl   108.43
# | epoch   5 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.116 | loss  4.64 | ppl   103.71
# | epoch   5 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.093 | loss  4.60 | ppl    99.68
# | epoch   5 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.097 | loss  4.62 | ppl   101.16
# | epoch   5 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.120 | loss  4.56 | ppl    95.33
# | epoch   5 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.206 | loss  4.63 | ppl   102.73
# | epoch   5 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.125 | loss  4.61 | ppl   100.63
# | epoch   5 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.067 | loss  4.66 | ppl   105.52
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 20.09s | valid loss 4.252 | valid ppl    70.23
# -----------------------------------------------------------------------------------------
# | epoch   6 |   100/ 1844 batches | lr 2.00 | ms/batch 8.301 | loss  4.61 | ppl    99.99
# | epoch   6 |   200/ 1844 batches | lr 2.00 | ms/batch 8.124 | loss  4.53 | ppl    92.90
# | epoch   6 |   300/ 1844 batches | lr 2.00 | ms/batch 8.123 | loss  4.45 | ppl    85.27
# | epoch   6 |   400/ 1844 batches | lr 2.00 | ms/batch 8.199 | loss  4.45 | ppl    85.45
# | epoch   6 |   500/ 1844 batches | lr 2.00 | ms/batch 8.204 | loss  4.45 | ppl    85.98
# | epoch   6 |   600/ 1844 batches | lr 2.00 | ms/batch 8.143 | loss  4.46 | ppl    86.77
# | epoch   6 |   700/ 1844 batches | lr 2.00 | ms/batch 8.205 | loss  4.45 | ppl    85.57
# | epoch   6 |   800/ 1844 batches | lr 2.00 | ms/batch 8.133 | loss  4.43 | ppl    84.18
# | epoch   6 |   900/ 1844 batches | lr 2.00 | ms/batch 8.109 | loss  4.44 | ppl    84.89
# | epoch   6 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.135 | loss  4.39 | ppl    80.85
# | epoch   6 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.216 | loss  4.46 | ppl    86.37
# | epoch   6 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.209 | loss  4.39 | ppl    80.39
# | epoch   6 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.187 | loss  4.37 | ppl    79.02
# | epoch   6 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.197 | loss  4.40 | ppl    81.82
# | epoch   6 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.202 | loss  4.33 | ppl    76.17
# | epoch   6 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.265 | loss  4.40 | ppl    81.46
# | epoch   6 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.168 | loss  4.39 | ppl    80.25
# | epoch   6 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.145 | loss  4.44 | ppl    84.62
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 20.22s | valid loss 4.010 | valid ppl    55.16
# -----------------------------------------------------------------------------------------
# | epoch   7 |   100/ 1844 batches | lr 2.00 | ms/batch 8.311 | loss  4.38 | ppl    80.08
# | epoch   7 |   200/ 1844 batches | lr 2.00 | ms/batch 8.143 | loss  4.32 | ppl    74.91
# | epoch   7 |   300/ 1844 batches | lr 2.00 | ms/batch 8.190 | loss  4.25 | ppl    70.12
# | epoch   7 |   400/ 1844 batches | lr 2.00 | ms/batch 8.242 | loss  4.23 | ppl    68.79
# | epoch   7 |   500/ 1844 batches | lr 2.00 | ms/batch 8.177 | loss  4.24 | ppl    69.07
# | epoch   7 |   600/ 1844 batches | lr 2.00 | ms/batch 8.203 | loss  4.25 | ppl    69.85
# | epoch   7 |   700/ 1844 batches | lr 2.00 | ms/batch 8.110 | loss  4.24 | ppl    69.29
# | epoch   7 |   800/ 1844 batches | lr 2.00 | ms/batch 8.139 | loss  4.21 | ppl    67.10
# | epoch   7 |   900/ 1844 batches | lr 2.00 | ms/batch 8.232 | loss  4.23 | ppl    68.59
# | epoch   7 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.228 | loss  4.18 | ppl    65.30
# | epoch   7 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.120 | loss  4.24 | ppl    69.23
# | epoch   7 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.140 | loss  4.19 | ppl    65.77
# | epoch   7 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.151 | loss  4.17 | ppl    64.71
# | epoch   7 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.268 | loss  4.20 | ppl    66.38
# | epoch   7 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.360 | loss  4.12 | ppl    61.81
# | epoch   7 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.198 | loss  4.19 | ppl    65.97
# | epoch   7 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.206 | loss  4.19 | ppl    65.75
# | epoch   7 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.165 | loss  4.23 | ppl    68.58
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 20.27s | valid loss 3.792 | valid ppl    44.35
# -----------------------------------------------------------------------------------------
# | epoch   8 |   100/ 1844 batches | lr 2.00 | ms/batch 8.276 | loss  4.20 | ppl    66.91
# | epoch   8 |   200/ 1844 batches | lr 2.00 | ms/batch 8.170 | loss  4.12 | ppl    61.80
# | epoch   8 |   300/ 1844 batches | lr 2.00 | ms/batch 8.137 | loss  4.05 | ppl    57.62
# | epoch   8 |   400/ 1844 batches | lr 2.00 | ms/batch 8.075 | loss  4.05 | ppl    57.48
# | epoch   8 |   500/ 1844 batches | lr 2.00 | ms/batch 8.238 | loss  4.04 | ppl    56.61
# | epoch   8 |   600/ 1844 batches | lr 2.00 | ms/batch 8.131 | loss  4.06 | ppl    57.86
# | epoch   8 |   700/ 1844 batches | lr 2.00 | ms/batch 8.217 | loss  4.03 | ppl    56.38
# | epoch   8 |   800/ 1844 batches | lr 2.00 | ms/batch 8.099 | loss  4.00 | ppl    54.64
# | epoch   8 |   900/ 1844 batches | lr 2.00 | ms/batch 8.237 | loss  4.06 | ppl    57.86
# | epoch   8 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.628 | loss  3.99 | ppl    54.00
# | epoch   8 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.284 | loss  4.08 | ppl    59.38
# | epoch   8 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.095 | loss  3.98 | ppl    53.56
# | epoch   8 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.198 | loss  3.96 | ppl    52.51
# | epoch   8 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.094 | loss  4.01 | ppl    55.35
# | epoch   8 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.126 | loss  3.95 | ppl    51.69
# | epoch   8 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.116 | loss  4.03 | ppl    56.41
# | epoch   8 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.148 | loss  4.00 | ppl    54.57
# | epoch   8 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.170 | loss  4.03 | ppl    56.35
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 20.22s | valid loss 3.602 | valid ppl    36.66
# -----------------------------------------------------------------------------------------
# | epoch   9 |   100/ 1844 batches | lr 2.00 | ms/batch 8.187 | loss  4.04 | ppl    56.55
# | epoch   9 |   200/ 1844 batches | lr 2.00 | ms/batch 8.079 | loss  3.93 | ppl    50.97
# | epoch   9 |   300/ 1844 batches | lr 2.00 | ms/batch 8.152 | loss  3.89 | ppl    48.98
# | epoch   9 |   400/ 1844 batches | lr 2.00 | ms/batch 8.109 | loss  3.86 | ppl    47.67
# | epoch   9 |   500/ 1844 batches | lr 2.00 | ms/batch 8.207 | loss  3.88 | ppl    48.53
# | epoch   9 |   600/ 1844 batches | lr 2.00 | ms/batch 8.079 | loss  3.87 | ppl    47.99
# | epoch   9 |   700/ 1844 batches | lr 2.00 | ms/batch 8.078 | loss  3.87 | ppl    48.02
# | epoch   9 |   800/ 1844 batches | lr 2.00 | ms/batch 8.256 | loss  3.83 | ppl    46.25
# | epoch   9 |   900/ 1844 batches | lr 2.00 | ms/batch 8.125 | loss  3.88 | ppl    48.26
# | epoch   9 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.119 | loss  3.82 | ppl    45.40
# | epoch   9 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.071 | loss  3.91 | ppl    49.92
# | epoch   9 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.174 | loss  3.82 | ppl    45.46
# | epoch   9 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.107 | loss  3.80 | ppl    44.77
# | epoch   9 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.175 | loss  3.84 | ppl    46.50
# | epoch   9 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.123 | loss  3.78 | ppl    43.79
# | epoch   9 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.076 | loss  3.85 | ppl    47.06
# | epoch   9 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.086 | loss  3.82 | ppl    45.64
# | epoch   9 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.155 | loss  3.89 | ppl    48.73
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 20.10s | valid loss 3.429 | valid ppl    30.83
# -----------------------------------------------------------------------------------------
# | epoch  10 |   100/ 1844 batches | lr 2.00 | ms/batch 8.260 | loss  3.89 | ppl    48.96
# | epoch  10 |   200/ 1844 batches | lr 2.00 | ms/batch 8.168 | loss  3.76 | ppl    42.98
# | epoch  10 |   300/ 1844 batches | lr 2.00 | ms/batch 8.161 | loss  3.71 | ppl    40.99
# | epoch  10 |   400/ 1844 batches | lr 2.00 | ms/batch 8.107 | loss  3.70 | ppl    40.30
# | epoch  10 |   500/ 1844 batches | lr 2.00 | ms/batch 8.153 | loss  3.72 | ppl    41.08
# | epoch  10 |   600/ 1844 batches | lr 2.00 | ms/batch 8.117 | loss  3.75 | ppl    42.72
# | epoch  10 |   700/ 1844 batches | lr 2.00 | ms/batch 8.125 | loss  3.71 | ppl    40.90
# | epoch  10 |   800/ 1844 batches | lr 2.00 | ms/batch 8.128 | loss  3.67 | ppl    39.44
# | epoch  10 |   900/ 1844 batches | lr 2.00 | ms/batch 8.195 | loss  3.72 | ppl    41.23
# | epoch  10 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.136 | loss  3.66 | ppl    38.77
# | epoch  10 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.151 | loss  3.75 | ppl    42.64
# | epoch  10 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.212 | loss  3.66 | ppl    38.97
# | epoch  10 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.315 | loss  3.64 | ppl    37.92
# | epoch  10 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.250 | loss  3.69 | ppl    40.02
# | epoch  10 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.121 | loss  3.65 | ppl    38.55
# | epoch  10 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.168 | loss  3.70 | ppl    40.28
# | epoch  10 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.110 | loss  3.66 | ppl    38.91
# | epoch  10 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.249 | loss  3.73 | ppl    41.70
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 20.22s | valid loss 3.266 | valid ppl    26.22
# -----------------------------------------------------------------------------------------
# | epoch  11 |   100/ 1844 batches | lr 2.00 | ms/batch 8.249 | loss  3.74 | ppl    41.99
# | epoch  11 |   200/ 1844 batches | lr 2.00 | ms/batch 8.214 | loss  3.62 | ppl    37.45
# | epoch  11 |   300/ 1844 batches | lr 2.00 | ms/batch 8.127 | loss  3.57 | ppl    35.61
# | epoch  11 |   400/ 1844 batches | lr 2.00 | ms/batch 8.155 | loss  3.57 | ppl    35.35
# | epoch  11 |   500/ 1844 batches | lr 2.00 | ms/batch 8.146 | loss  3.59 | ppl    36.09
# | epoch  11 |   600/ 1844 batches | lr 2.00 | ms/batch 8.251 | loss  3.60 | ppl    36.75
# | epoch  11 |   700/ 1844 batches | lr 2.00 | ms/batch 8.154 | loss  3.55 | ppl    34.98
# | epoch  11 |   800/ 1844 batches | lr 2.00 | ms/batch 8.125 | loss  3.52 | ppl    33.75
# | epoch  11 |   900/ 1844 batches | lr 2.00 | ms/batch 8.052 | loss  3.59 | ppl    36.37
# | epoch  11 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.098 | loss  3.53 | ppl    34.00
# | epoch  11 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.125 | loss  3.61 | ppl    36.87
# | epoch  11 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.177 | loss  3.55 | ppl    34.85
# | epoch  11 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.081 | loss  3.51 | ppl    33.50
# | epoch  11 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.109 | loss  3.57 | ppl    35.45
# | epoch  11 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.087 | loss  3.49 | ppl    32.89
# | epoch  11 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.162 | loss  3.57 | ppl    35.43
# | epoch  11 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.100 | loss  3.53 | ppl    34.24
# | epoch  11 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.259 | loss  3.57 | ppl    35.61
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 20.14s | valid loss 3.109 | valid ppl    22.39
# -----------------------------------------------------------------------------------------
# | epoch  12 |   100/ 1844 batches | lr 2.00 | ms/batch 8.288 | loss  3.61 | ppl    37.00
# | epoch  12 |   200/ 1844 batches | lr 2.00 | ms/batch 8.119 | loss  3.50 | ppl    33.20
# | epoch  12 |   300/ 1844 batches | lr 2.00 | ms/batch 8.103 | loss  3.42 | ppl    30.71
# | epoch  12 |   400/ 1844 batches | lr 2.00 | ms/batch 8.194 | loss  3.43 | ppl    30.92
# | epoch  12 |   500/ 1844 batches | lr 2.00 | ms/batch 8.163 | loss  3.45 | ppl    31.64
# | epoch  12 |   600/ 1844 batches | lr 2.00 | ms/batch 8.163 | loss  3.48 | ppl    32.48
# | epoch  12 |   700/ 1844 batches | lr 2.00 | ms/batch 8.170 | loss  3.42 | ppl    30.51
# | epoch  12 |   800/ 1844 batches | lr 2.00 | ms/batch 8.081 | loss  3.38 | ppl    29.33
# | epoch  12 |   900/ 1844 batches | lr 2.00 | ms/batch 8.196 | loss  3.44 | ppl    31.08
# | epoch  12 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.106 | loss  3.39 | ppl    29.73
# | epoch  12 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.175 | loss  3.49 | ppl    32.69
# | epoch  12 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.098 | loss  3.41 | ppl    30.13
# | epoch  12 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.109 | loss  3.34 | ppl    28.30
# | epoch  12 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.135 | loss  3.42 | ppl    30.72
# | epoch  12 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.074 | loss  3.36 | ppl    28.86
# | epoch  12 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.170 | loss  3.43 | ppl    30.86
# | epoch  12 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.114 | loss  3.40 | ppl    29.91
# | epoch  12 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.048 | loss  3.44 | ppl    31.07
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 20.15s | valid loss 2.973 | valid ppl    19.55
# -----------------------------------------------------------------------------------------
# | epoch  13 |   100/ 1844 batches | lr 2.00 | ms/batch 8.233 | loss  3.48 | ppl    32.44
# | epoch  13 |   200/ 1844 batches | lr 2.00 | ms/batch 8.077 | loss  3.36 | ppl    28.71
# | epoch  13 |   300/ 1844 batches | lr 2.00 | ms/batch 8.143 | loss  3.30 | ppl    27.03
# | epoch  13 |   400/ 1844 batches | lr 2.00 | ms/batch 8.052 | loss  3.30 | ppl    27.07
# | epoch  13 |   500/ 1844 batches | lr 2.00 | ms/batch 8.073 | loss  3.34 | ppl    28.24
# | epoch  13 |   600/ 1844 batches | lr 2.00 | ms/batch 8.085 | loss  3.35 | ppl    28.61
# | epoch  13 |   700/ 1844 batches | lr 2.00 | ms/batch 8.153 | loss  3.31 | ppl    27.35
# | epoch  13 |   800/ 1844 batches | lr 2.00 | ms/batch 8.071 | loss  3.25 | ppl    25.74
# | epoch  13 |   900/ 1844 batches | lr 2.00 | ms/batch 8.162 | loss  3.36 | ppl    28.66
# | epoch  13 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.145 | loss  3.25 | ppl    25.73
# | epoch  13 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.149 | loss  3.38 | ppl    29.27
# | epoch  13 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.119 | loss  3.29 | ppl    26.80
# | epoch  13 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.221 | loss  3.24 | ppl    25.55
# | epoch  13 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.125 | loss  3.28 | ppl    26.65
# | epoch  13 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.154 | loss  3.26 | ppl    26.01
# | epoch  13 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.138 | loss  3.31 | ppl    27.30
# | epoch  13 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.099 | loss  3.26 | ppl    26.10
# | epoch  13 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.141 | loss  3.31 | ppl    27.51
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 20.16s | valid loss 2.822 | valid ppl    16.81
# -----------------------------------------------------------------------------------------
# | epoch  14 |   100/ 1844 batches | lr 2.00 | ms/batch 8.174 | loss  3.36 | ppl    28.83
# | epoch  14 |   200/ 1844 batches | lr 2.00 | ms/batch 8.127 | loss  3.23 | ppl    25.33
# | epoch  14 |   300/ 1844 batches | lr 2.00 | ms/batch 8.137 | loss  3.17 | ppl    23.78
# | epoch  14 |   400/ 1844 batches | lr 2.00 | ms/batch 8.172 | loss  3.17 | ppl    23.81
# | epoch  14 |   500/ 1844 batches | lr 2.00 | ms/batch 8.119 | loss  3.23 | ppl    25.29
# | epoch  14 |   600/ 1844 batches | lr 2.00 | ms/batch 8.106 | loss  3.23 | ppl    25.36
# | epoch  14 |   700/ 1844 batches | lr 2.00 | ms/batch 8.150 | loss  3.17 | ppl    23.91
# | epoch  14 |   800/ 1844 batches | lr 2.00 | ms/batch 8.144 | loss  3.13 | ppl    22.98
# | epoch  14 |   900/ 1844 batches | lr 2.00 | ms/batch 8.178 | loss  3.21 | ppl    24.82
# | epoch  14 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.068 | loss  3.13 | ppl    22.81
# | epoch  14 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.114 | loss  3.27 | ppl    26.19
# | epoch  14 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.084 | loss  3.16 | ppl    23.66
# | epoch  14 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.170 | loss  3.13 | ppl    22.87
# | epoch  14 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.144 | loss  3.20 | ppl    24.64
# | epoch  14 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.129 | loss  3.12 | ppl    22.55
# | epoch  14 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.088 | loss  3.20 | ppl    24.63
# | epoch  14 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.118 | loss  3.13 | ppl    22.92
# | epoch  14 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.229 | loss  3.18 | ppl    24.12
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 20.13s | valid loss 2.674 | valid ppl    14.49
# -----------------------------------------------------------------------------------------
# | epoch  15 |   100/ 1844 batches | lr 2.00 | ms/batch 8.277 | loss  3.24 | ppl    25.46
# | epoch  15 |   200/ 1844 batches | lr 2.00 | ms/batch 8.215 | loss  3.10 | ppl    22.24
# | epoch  15 |   300/ 1844 batches | lr 2.00 | ms/batch 8.129 | loss  3.06 | ppl    21.38
# | epoch  15 |   400/ 1844 batches | lr 2.00 | ms/batch 8.097 | loss  3.04 | ppl    20.98
# | epoch  15 |   500/ 1844 batches | lr 2.00 | ms/batch 8.088 | loss  3.14 | ppl    23.01
# | epoch  15 |   600/ 1844 batches | lr 2.00 | ms/batch 8.082 | loss  3.07 | ppl    21.64
# | epoch  15 |   700/ 1844 batches | lr 2.00 | ms/batch 8.106 | loss  3.05 | ppl    21.11
# | epoch  15 |   800/ 1844 batches | lr 2.00 | ms/batch 8.101 | loss  3.02 | ppl    20.59
# | epoch  15 |   900/ 1844 batches | lr 2.00 | ms/batch 8.109 | loss  3.11 | ppl    22.49
# | epoch  15 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.202 | loss  3.02 | ppl    20.55
# | epoch  15 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.115 | loss  3.12 | ppl    22.75
# | epoch  15 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.146 | loss  3.05 | ppl    21.01
# | epoch  15 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.073 | loss  2.99 | ppl    19.95
# | epoch  15 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.105 | loss  3.04 | ppl    20.98
# | epoch  15 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.103 | loss  2.97 | ppl    19.49
# | epoch  15 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.129 | loss  3.05 | ppl    21.15
# | epoch  15 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.174 | loss  3.01 | ppl    20.19
# | epoch  15 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.114 | loss  3.08 | ppl    21.67
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 20.14s | valid loss 2.519 | valid ppl    12.41
# -----------------------------------------------------------------------------------------
# | epoch  16 |   100/ 1844 batches | lr 2.00 | ms/batch 8.289 | loss  3.11 | ppl    22.39
# | epoch  16 |   200/ 1844 batches | lr 2.00 | ms/batch 8.161 | loss  2.98 | ppl    19.76
# | epoch  16 |   300/ 1844 batches | lr 2.00 | ms/batch 8.114 | loss  2.93 | ppl    18.78
# | epoch  16 |   400/ 1844 batches | lr 2.00 | ms/batch 8.139 | loss  2.95 | ppl    19.14
# | epoch  16 |   500/ 1844 batches | lr 2.00 | ms/batch 8.106 | loss  3.00 | ppl    20.00
# | epoch  16 |   600/ 1844 batches | lr 2.00 | ms/batch 8.187 | loss  2.97 | ppl    19.45
# | epoch  16 |   700/ 1844 batches | lr 2.00 | ms/batch 8.154 | loss  2.94 | ppl    18.96
# | epoch  16 |   800/ 1844 batches | lr 2.00 | ms/batch 8.217 | loss  2.89 | ppl    18.07
# | epoch  16 |   900/ 1844 batches | lr 2.00 | ms/batch 8.074 | loss  2.97 | ppl    19.52
# | epoch  16 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.149 | loss  2.90 | ppl    18.15
# | epoch  16 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.166 | loss  2.97 | ppl    19.45
# | epoch  16 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.314 | loss  2.92 | ppl    18.54
# | epoch  16 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.072 | loss  2.87 | ppl    17.60
# | epoch  16 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.131 | loss  2.95 | ppl    19.08
# | epoch  16 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.122 | loss  2.88 | ppl    17.74
# | epoch  16 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.145 | loss  2.96 | ppl    19.25
# | epoch  16 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.149 | loss  2.91 | ppl    18.28
# | epoch  16 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.160 | loss  2.96 | ppl    19.28
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 20.20s | valid loss 2.402 | valid ppl    11.05
# -----------------------------------------------------------------------------------------
# | epoch  17 |   100/ 1844 batches | lr 2.00 | ms/batch 8.267 | loss  3.02 | ppl    20.41
# | epoch  17 |   200/ 1844 batches | lr 2.00 | ms/batch 8.126 | loss  2.86 | ppl    17.51
# | epoch  17 |   300/ 1844 batches | lr 2.00 | ms/batch 8.189 | loss  2.84 | ppl    17.04
# | epoch  17 |   400/ 1844 batches | lr 2.00 | ms/batch 8.100 | loss  2.86 | ppl    17.47
# | epoch  17 |   500/ 1844 batches | lr 2.00 | ms/batch 8.147 | loss  2.90 | ppl    18.20
# | epoch  17 |   600/ 1844 batches | lr 2.00 | ms/batch 8.138 | loss  2.88 | ppl    17.77
# | epoch  17 |   700/ 1844 batches | lr 2.00 | ms/batch 8.129 | loss  2.86 | ppl    17.44
# | epoch  17 |   800/ 1844 batches | lr 2.00 | ms/batch 8.151 | loss  2.78 | ppl    16.09
# | epoch  17 |   900/ 1844 batches | lr 2.00 | ms/batch 8.122 | loss  2.89 | ppl    18.00
# | epoch  17 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.078 | loss  2.79 | ppl    16.35
# | epoch  17 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.097 | loss  2.88 | ppl    17.90
# | epoch  17 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.105 | loss  2.82 | ppl    16.82
# | epoch  17 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.056 | loss  2.74 | ppl    15.44
# | epoch  17 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.079 | loss  2.85 | ppl    17.20
# | epoch  17 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.087 | loss  2.75 | ppl    15.62
# | epoch  17 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.093 | loss  2.86 | ppl    17.47
# | epoch  17 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.192 | loss  2.79 | ppl    16.22
# | epoch  17 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.062 | loss  2.81 | ppl    16.66
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 20.07s | valid loss 2.255 | valid ppl     9.54
# -----------------------------------------------------------------------------------------
# | epoch  18 |   100/ 1844 batches | lr 2.00 | ms/batch 8.239 | loss  2.87 | ppl    17.69
# | epoch  18 |   200/ 1844 batches | lr 2.00 | ms/batch 8.124 | loss  2.77 | ppl    16.03
# | epoch  18 |   300/ 1844 batches | lr 2.00 | ms/batch 8.142 | loss  2.71 | ppl    15.10
# | epoch  18 |   400/ 1844 batches | lr 2.00 | ms/batch 8.123 | loss  2.71 | ppl    14.96
# | epoch  18 |   500/ 1844 batches | lr 2.00 | ms/batch 8.129 | loss  2.76 | ppl    15.86
# | epoch  18 |   600/ 1844 batches | lr 2.00 | ms/batch 8.144 | loss  2.75 | ppl    15.69
# | epoch  18 |   700/ 1844 batches | lr 2.00 | ms/batch 8.102 | loss  2.73 | ppl    15.32
# | epoch  18 |   800/ 1844 batches | lr 2.00 | ms/batch 8.092 | loss  2.68 | ppl    14.53
# | epoch  18 |   900/ 1844 batches | lr 2.00 | ms/batch 8.216 | loss  2.79 | ppl    16.25
# | epoch  18 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.110 | loss  2.69 | ppl    14.80
# | epoch  18 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.146 | loss  2.75 | ppl    15.69
# | epoch  18 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.165 | loss  2.71 | ppl    15.07
# | epoch  18 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.233 | loss  2.65 | ppl    14.13
# | epoch  18 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.138 | loss  2.71 | ppl    14.99
# | epoch  18 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.130 | loss  2.64 | ppl    14.06
# | epoch  18 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.145 | loss  2.76 | ppl    15.79
# | epoch  18 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.105 | loss  2.68 | ppl    14.60
# | epoch  18 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.119 | loss  2.73 | ppl    15.27
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 20.18s | valid loss 2.130 | valid ppl     8.41
# -----------------------------------------------------------------------------------------
# | epoch  19 |   100/ 1844 batches | lr 2.00 | ms/batch 8.248 | loss  2.79 | ppl    16.22
# | epoch  19 |   200/ 1844 batches | lr 2.00 | ms/batch 8.153 | loss  2.66 | ppl    14.37
# | epoch  19 |   300/ 1844 batches | lr 2.00 | ms/batch 8.112 | loss  2.60 | ppl    13.40
# | epoch  19 |   400/ 1844 batches | lr 2.00 | ms/batch 8.197 | loss  2.62 | ppl    13.72
# | epoch  19 |   500/ 1844 batches | lr 2.00 | ms/batch 8.108 | loss  2.66 | ppl    14.36
# | epoch  19 |   600/ 1844 batches | lr 2.00 | ms/batch 8.172 | loss  2.63 | ppl    13.83
# | epoch  19 |   700/ 1844 batches | lr 2.00 | ms/batch 8.079 | loss  2.64 | ppl    13.95
# | epoch  19 |   800/ 1844 batches | lr 2.00 | ms/batch 8.153 | loss  2.52 | ppl    12.48
# | epoch  19 |   900/ 1844 batches | lr 2.00 | ms/batch 8.149 | loss  2.65 | ppl    14.17
# | epoch  19 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.201 | loss  2.58 | ppl    13.14
# | epoch  19 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.226 | loss  2.66 | ppl    14.30
# | epoch  19 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.083 | loss  2.58 | ppl    13.16
# | epoch  19 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.190 | loss  2.55 | ppl    12.77
# | epoch  19 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.134 | loss  2.60 | ppl    13.42
# | epoch  19 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.066 | loss  2.55 | ppl    12.86
# | epoch  19 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.119 | loss  2.64 | ppl    14.06
# | epoch  19 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.152 | loss  2.58 | ppl    13.21
# | epoch  19 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.125 | loss  2.65 | ppl    14.17
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 20.17s | valid loss 2.031 | valid ppl     7.62
# -----------------------------------------------------------------------------------------
# | epoch  20 |   100/ 1844 batches | lr 2.00 | ms/batch 8.153 | loss  2.69 | ppl    14.73
# | epoch  20 |   200/ 1844 batches | lr 2.00 | ms/batch 8.151 | loss  2.55 | ppl    12.81
# | epoch  20 |   300/ 1844 batches | lr 2.00 | ms/batch 8.175 | loss  2.49 | ppl    12.09
# | epoch  20 |   400/ 1844 batches | lr 2.00 | ms/batch 8.189 | loss  2.51 | ppl    12.27
# | epoch  20 |   500/ 1844 batches | lr 2.00 | ms/batch 8.194 | loss  2.55 | ppl    12.77
# | epoch  20 |   600/ 1844 batches | lr 2.00 | ms/batch 8.076 | loss  2.56 | ppl    12.89
# | epoch  20 |   700/ 1844 batches | lr 2.00 | ms/batch 8.112 | loss  2.52 | ppl    12.41
# | epoch  20 |   800/ 1844 batches | lr 2.00 | ms/batch 8.095 | loss  2.44 | ppl    11.45
# | epoch  20 |   900/ 1844 batches | lr 2.00 | ms/batch 8.142 | loss  2.54 | ppl    12.71
# | epoch  20 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.268 | loss  2.46 | ppl    11.72
# | epoch  20 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.077 | loss  2.58 | ppl    13.16
# | epoch  20 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.066 | loss  2.49 | ppl    12.10
# | epoch  20 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.142 | loss  2.45 | ppl    11.53
# | epoch  20 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.176 | loss  2.49 | ppl    12.09
# | epoch  20 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.071 | loss  2.45 | ppl    11.58
# | epoch  20 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.091 | loss  2.51 | ppl    12.30
# | epoch  20 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.079 | loss  2.46 | ppl    11.76
# | epoch  20 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.149 | loss  2.52 | ppl    12.38
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 20.12s | valid loss 1.922 | valid ppl     6.83
# -----------------------------------------------------------------------------------------
# | epoch  21 |   100/ 1844 batches | lr 2.00 | ms/batch 8.231 | loss  2.58 | ppl    13.24
# | epoch  21 |   200/ 1844 batches | lr 2.00 | ms/batch 8.179 | loss  2.44 | ppl    11.48
# | epoch  21 |   300/ 1844 batches | lr 2.00 | ms/batch 8.110 | loss  2.39 | ppl    10.88
# | epoch  21 |   400/ 1844 batches | lr 2.00 | ms/batch 8.111 | loss  2.41 | ppl    11.11
# | epoch  21 |   500/ 1844 batches | lr 2.00 | ms/batch 8.112 | loss  2.47 | ppl    11.81
# | epoch  21 |   600/ 1844 batches | lr 2.00 | ms/batch 8.115 | loss  2.44 | ppl    11.44
# | epoch  21 |   700/ 1844 batches | lr 2.00 | ms/batch 8.080 | loss  2.40 | ppl    10.97
# | epoch  21 |   800/ 1844 batches | lr 2.00 | ms/batch 8.124 | loss  2.36 | ppl    10.63
# | epoch  21 |   900/ 1844 batches | lr 2.00 | ms/batch 8.074 | loss  2.44 | ppl    11.51
# | epoch  21 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.079 | loss  2.37 | ppl    10.69
# | epoch  21 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.197 | loss  2.49 | ppl    12.01
# | epoch  21 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.096 | loss  2.40 | ppl    11.08
# | epoch  21 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.339 | loss  2.34 | ppl    10.42
# | epoch  21 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.089 | loss  2.40 | ppl    11.01
# | epoch  21 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.075 | loss  2.37 | ppl    10.74
# | epoch  21 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.164 | loss  2.45 | ppl    11.64
# | epoch  21 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.122 | loss  2.36 | ppl    10.58
# | epoch  21 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.067 | loss  2.43 | ppl    11.35
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 20.07s | valid loss 1.788 | valid ppl     5.98
# -----------------------------------------------------------------------------------------
# | epoch  22 |   100/ 1844 batches | lr 2.00 | ms/batch 8.254 | loss  2.47 | ppl    11.78
# | epoch  22 |   200/ 1844 batches | lr 2.00 | ms/batch 8.124 | loss  2.37 | ppl    10.66
# | epoch  22 |   300/ 1844 batches | lr 2.00 | ms/batch 8.135 | loss  2.29 | ppl     9.83
# | epoch  22 |   400/ 1844 batches | lr 2.00 | ms/batch 8.152 | loss  2.30 | ppl     9.94
# | epoch  22 |   500/ 1844 batches | lr 2.00 | ms/batch 8.173 | loss  2.38 | ppl    10.84
# | epoch  22 |   600/ 1844 batches | lr 2.00 | ms/batch 8.206 | loss  2.35 | ppl    10.43
# | epoch  22 |   700/ 1844 batches | lr 2.00 | ms/batch 8.160 | loss  2.33 | ppl    10.23
# | epoch  22 |   800/ 1844 batches | lr 2.00 | ms/batch 8.106 | loss  2.26 | ppl     9.56
# | epoch  22 |   900/ 1844 batches | lr 2.00 | ms/batch 8.141 | loss  2.34 | ppl    10.34
# | epoch  22 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.181 | loss  2.25 | ppl     9.51
# | epoch  22 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.366 | loss  2.37 | ppl    10.68
# | epoch  22 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.232 | loss  2.29 | ppl     9.88
# | epoch  22 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.120 | loss  2.28 | ppl     9.75
# | epoch  22 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.113 | loss  2.30 | ppl     9.97
# | epoch  22 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.124 | loss  2.27 | ppl     9.71
# | epoch  22 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.133 | loss  2.33 | ppl    10.28
# | epoch  22 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.123 | loss  2.27 | ppl     9.68
# | epoch  22 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.221 | loss  2.34 | ppl    10.34
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 20.23s | valid loss 1.707 | valid ppl     5.51
# -----------------------------------------------------------------------------------------
# | epoch  23 |   100/ 1844 batches | lr 2.00 | ms/batch 8.382 | loss  2.36 | ppl    10.59
# | epoch  23 |   200/ 1844 batches | lr 2.00 | ms/batch 8.261 | loss  2.26 | ppl     9.59
# | epoch  23 |   300/ 1844 batches | lr 2.00 | ms/batch 8.076 | loss  2.22 | ppl     9.17
# | epoch  23 |   400/ 1844 batches | lr 2.00 | ms/batch 8.141 | loss  2.21 | ppl     9.11
# | epoch  23 |   500/ 1844 batches | lr 2.00 | ms/batch 8.124 | loss  2.25 | ppl     9.48
# | epoch  23 |   600/ 1844 batches | lr 2.00 | ms/batch 8.444 | loss  2.24 | ppl     9.43
# | epoch  23 |   700/ 1844 batches | lr 2.00 | ms/batch 8.315 | loss  2.20 | ppl     9.05
# | epoch  23 |   800/ 1844 batches | lr 2.00 | ms/batch 8.092 | loss  2.17 | ppl     8.75
# | epoch  23 |   900/ 1844 batches | lr 2.00 | ms/batch 8.111 | loss  2.21 | ppl     9.16
# | epoch  23 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.115 | loss  2.18 | ppl     8.83
# | epoch  23 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.184 | loss  2.30 | ppl     9.95
# | epoch  23 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.246 | loss  2.23 | ppl     9.29
# | epoch  23 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.115 | loss  2.17 | ppl     8.74
# | epoch  23 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.106 | loss  2.22 | ppl     9.25
# | epoch  23 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.105 | loss  2.18 | ppl     8.83
# | epoch  23 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.208 | loss  2.26 | ppl     9.62
# | epoch  23 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.113 | loss  2.19 | ppl     8.91
# | epoch  23 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.120 | loss  2.25 | ppl     9.45
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 20.20s | valid loss 1.583 | valid ppl     4.87
# -----------------------------------------------------------------------------------------
# | epoch  24 |   100/ 1844 batches | lr 2.00 | ms/batch 8.210 | loss  2.30 | ppl    10.00
# | epoch  24 |   200/ 1844 batches | lr 2.00 | ms/batch 8.121 | loss  2.18 | ppl     8.88
# | epoch  24 |   300/ 1844 batches | lr 2.00 | ms/batch 8.141 | loss  2.10 | ppl     8.20
# | epoch  24 |   400/ 1844 batches | lr 2.00 | ms/batch 8.109 | loss  2.13 | ppl     8.39
# | epoch  24 |   500/ 1844 batches | lr 2.00 | ms/batch 8.106 | loss  2.21 | ppl     9.11
# | epoch  24 |   600/ 1844 batches | lr 2.00 | ms/batch 8.075 | loss  2.18 | ppl     8.87
# | epoch  24 |   700/ 1844 batches | lr 2.00 | ms/batch 8.044 | loss  2.14 | ppl     8.50
# | epoch  24 |   800/ 1844 batches | lr 2.00 | ms/batch 8.123 | loss  2.07 | ppl     7.95
# | epoch  24 |   900/ 1844 batches | lr 2.00 | ms/batch 8.136 | loss  2.18 | ppl     8.83
# | epoch  24 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.127 | loss  2.06 | ppl     7.89
# | epoch  24 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.082 | loss  2.19 | ppl     8.92
# | epoch  24 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.075 | loss  2.10 | ppl     8.16
# | epoch  24 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.228 | loss  2.07 | ppl     7.96
# | epoch  24 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.366 | loss  2.16 | ppl     8.68
# | epoch  24 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.183 | loss  2.08 | ppl     8.02
# | epoch  24 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.136 | loss  2.15 | ppl     8.55
# | epoch  24 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.075 | loss  2.10 | ppl     8.14
# | epoch  24 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.121 | loss  2.18 | ppl     8.86
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 20.07s | valid loss 1.498 | valid ppl     4.47
# -----------------------------------------------------------------------------------------
# | epoch  25 |   100/ 1844 batches | lr 2.00 | ms/batch 8.277 | loss  2.22 | ppl     9.17
# | epoch  25 |   200/ 1844 batches | lr 2.00 | ms/batch 8.175 | loss  2.12 | ppl     8.32
# | epoch  25 |   300/ 1844 batches | lr 2.00 | ms/batch 8.189 | loss  2.01 | ppl     7.48
# | epoch  25 |   400/ 1844 batches | lr 2.00 | ms/batch 8.160 | loss  2.06 | ppl     7.88
# | epoch  25 |   500/ 1844 batches | lr 2.00 | ms/batch 8.141 | loss  2.12 | ppl     8.33
# | epoch  25 |   600/ 1844 batches | lr 2.00 | ms/batch 8.144 | loss  2.09 | ppl     8.07
# | epoch  25 |   700/ 1844 batches | lr 2.00 | ms/batch 8.154 | loss  2.03 | ppl     7.60
# | epoch  25 |   800/ 1844 batches | lr 2.00 | ms/batch 8.176 | loss  2.00 | ppl     7.39
# | epoch  25 |   900/ 1844 batches | lr 2.00 | ms/batch 8.193 | loss  2.11 | ppl     8.24
# | epoch  25 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.231 | loss  2.01 | ppl     7.48
# | epoch  25 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.125 | loss  2.13 | ppl     8.40
# | epoch  25 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.150 | loss  2.07 | ppl     7.93
# | epoch  25 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.142 | loss  1.99 | ppl     7.33
# | epoch  25 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.194 | loss  2.08 | ppl     8.02
# | epoch  25 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.126 | loss  2.00 | ppl     7.39
# | epoch  25 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.113 | loss  2.08 | ppl     7.99
# | epoch  25 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.133 | loss  2.02 | ppl     7.50
# | epoch  25 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.109 | loss  2.09 | ppl     8.12
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 20.24s | valid loss 1.442 | valid ppl     4.23
# -----------------------------------------------------------------------------------------
# | epoch  26 |   100/ 1844 batches | lr 2.00 | ms/batch 8.401 | loss  2.13 | ppl     8.43
# | epoch  26 |   200/ 1844 batches | lr 2.00 | ms/batch 8.244 | loss  2.01 | ppl     7.48
# | epoch  26 |   300/ 1844 batches | lr 2.00 | ms/batch 8.074 | loss  1.95 | ppl     7.03
# | epoch  26 |   400/ 1844 batches | lr 2.00 | ms/batch 8.123 | loss  1.98 | ppl     7.28
# | epoch  26 |   500/ 1844 batches | lr 2.00 | ms/batch 8.096 | loss  2.04 | ppl     7.68
# | epoch  26 |   600/ 1844 batches | lr 2.00 | ms/batch 8.104 | loss  2.00 | ppl     7.35
# | epoch  26 |   700/ 1844 batches | lr 2.00 | ms/batch 8.214 | loss  1.97 | ppl     7.15
# | epoch  26 |   800/ 1844 batches | lr 2.00 | ms/batch 8.119 | loss  1.92 | ppl     6.80
# | epoch  26 |   900/ 1844 batches | lr 2.00 | ms/batch 8.144 | loss  2.00 | ppl     7.42
# | epoch  26 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.182 | loss  1.98 | ppl     7.23
# | epoch  26 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.099 | loss  2.05 | ppl     7.75
# | epoch  26 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.155 | loss  2.03 | ppl     7.58
# | epoch  26 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.142 | loss  1.93 | ppl     6.89
# | epoch  26 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.130 | loss  1.98 | ppl     7.23
# | epoch  26 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.149 | loss  1.90 | ppl     6.72
# | epoch  26 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.116 | loss  2.05 | ppl     7.73
# | epoch  26 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.162 | loss  1.95 | ppl     7.01
# ...
# | epoch  32 |   900/ 1844 batches | lr 2.00 | ms/batch 8.099 | loss  1.68 | ppl     5.36
# | epoch  32 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.117 | loss  1.60 | ppl     4.96
# | epoch  32 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.082 | loss  1.68 | ppl     5.38
# | epoch  32 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.078 | loss  1.64 | ppl     5.17
# | epoch  32 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.082 | loss  1.57 | ppl     4.83
# | epoch  32 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.035 | loss  1.67 | ppl     5.30
# | epoch  32 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.129 | loss  1.64 | ppl     5.18
# | epoch  32 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.163 | loss  1.73 | ppl     5.62
# | epoch  32 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.094 | loss  1.64 | ppl     5.14
# | epoch  32 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.196 | loss  1.68 | ppl     5.37
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 20.10s | valid loss 1.033 | valid ppl     2.81
# -----------------------------------------------------------------------------------------
# | epoch  33 |   100/ 1844 batches | lr 2.00 | ms/batch 8.329 | loss  1.72 | ppl     5.61
# | epoch  33 |   200/ 1844 batches | lr 2.00 | ms/batch 8.156 | loss  1.63 | ppl     5.10
# | epoch  33 |   300/ 1844 batches | lr 2.00 | ms/batch 8.139 | loss  1.53 | ppl     4.63
# | epoch  33 |   400/ 1844 batches | lr 2.00 | ms/batch 8.253 | loss  1.60 | ppl     4.96
# | epoch  33 |   500/ 1844 batches | lr 2.00 | ms/batch 8.042 | loss  1.64 | ppl     5.16
# | epoch  33 |   600/ 1844 batches | lr 2.00 | ms/batch 8.134 | loss  1.65 | ppl     5.19
# | epoch  33 |   700/ 1844 batches | lr 2.00 | ms/batch 8.069 | loss  1.59 | ppl     4.91
# | epoch  33 |   800/ 1844 batches | lr 2.00 | ms/batch 8.190 | loss  1.55 | ppl     4.71
# | epoch  33 |   900/ 1844 batches | lr 2.00 | ms/batch 8.173 | loss  1.62 | ppl     5.07
# | epoch  33 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.100 | loss  1.58 | ppl     4.88
# | epoch  33 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.095 | loss  1.68 | ppl     5.38
# | epoch  33 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.226 | loss  1.62 | ppl     5.07
# | epoch  33 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.061 | loss  1.55 | ppl     4.71
# | epoch  33 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.120 | loss  1.64 | ppl     5.17
# | epoch  33 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.092 | loss  1.56 | ppl     4.76
# | epoch  33 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.136 | loss  1.67 | ppl     5.33
# | epoch  33 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.144 | loss  1.58 | ppl     4.84
# | epoch  33 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.147 | loss  1.65 | ppl     5.20
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 20.14s | valid loss 1.015 | valid ppl     2.76
# -----------------------------------------------------------------------------------------
# | epoch  34 |   100/ 1844 batches | lr 2.00 | ms/batch 8.271 | loss  1.69 | ppl     5.43
# | epoch  34 |   200/ 1844 batches | lr 2.00 | ms/batch 8.178 | loss  1.59 | ppl     4.88
# | epoch  34 |   300/ 1844 batches | lr 2.00 | ms/batch 8.233 | loss  1.53 | ppl     4.64
# | epoch  34 |   400/ 1844 batches | lr 2.00 | ms/batch 8.120 | loss  1.54 | ppl     4.67
# | epoch  34 |   500/ 1844 batches | lr 2.00 | ms/batch 8.211 | loss  1.59 | ppl     4.90
# | epoch  34 |   600/ 1844 batches | lr 2.00 | ms/batch 8.163 | loss  1.58 | ppl     4.84
# | epoch  34 |   700/ 1844 batches | lr 2.00 | ms/batch 8.125 | loss  1.54 | ppl     4.67
# | epoch  34 |   800/ 1844 batches | lr 2.00 | ms/batch 8.267 | loss  1.51 | ppl     4.54
# | epoch  34 |   900/ 1844 batches | lr 2.00 | ms/batch 8.069 | loss  1.62 | ppl     5.05
# | epoch  34 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.160 | loss  1.53 | ppl     4.61
# | epoch  34 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.150 | loss  1.61 | ppl     5.02
# | epoch  34 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.160 | loss  1.57 | ppl     4.82
# | epoch  34 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.187 | loss  1.52 | ppl     4.58
# | epoch  34 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.073 | loss  1.59 | ppl     4.90
# | epoch  34 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.153 | loss  1.50 | ppl     4.48
# | epoch  34 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.115 | loss  1.58 | ppl     4.87
# | epoch  34 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.080 | loss  1.50 | ppl     4.49
# | epoch  34 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.307 | loss  1.60 | ppl     4.93
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 20.21s | valid loss 0.976 | valid ppl     2.65
# -----------------------------------------------------------------------------------------
# | epoch  35 |   100/ 1844 batches | lr 2.00 | ms/batch 8.327 | loss  1.65 | ppl     5.21
# | epoch  35 |   200/ 1844 batches | lr 2.00 | ms/batch 8.153 | loss  1.52 | ppl     4.59
# | epoch  35 |   300/ 1844 batches | lr 2.00 | ms/batch 8.148 | loss  1.52 | ppl     4.57
# | epoch  35 |   400/ 1844 batches | lr 2.00 | ms/batch 8.157 | loss  1.53 | ppl     4.60
# | epoch  35 |   500/ 1844 batches | lr 2.00 | ms/batch 8.083 | loss  1.56 | ppl     4.78
# | epoch  35 |   600/ 1844 batches | lr 2.00 | ms/batch 8.179 | loss  1.53 | ppl     4.63
# | epoch  35 |   700/ 1844 batches | lr 2.00 | ms/batch 8.078 | loss  1.50 | ppl     4.47
# | epoch  35 |   800/ 1844 batches | lr 2.00 | ms/batch 8.323 | loss  1.45 | ppl     4.27
# | epoch  35 |   900/ 1844 batches | lr 2.00 | ms/batch 8.217 | loss  1.52 | ppl     4.57
# | epoch  35 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.151 | loss  1.51 | ppl     4.53
# | epoch  35 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.156 | loss  1.57 | ppl     4.80
# | epoch  35 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.118 | loss  1.53 | ppl     4.60
# | epoch  35 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.114 | loss  1.52 | ppl     4.56
# | epoch  35 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.170 | loss  1.55 | ppl     4.70
# | epoch  35 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.170 | loss  1.47 | ppl     4.36
# | epoch  35 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.136 | loss  1.56 | ppl     4.77
# | epoch  35 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.282 | loss  1.49 | ppl     4.43
# | epoch  35 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.387 | loss  1.58 | ppl     4.85
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 20.19s | valid loss 0.913 | valid ppl     2.49
# -----------------------------------------------------------------------------------------
# | epoch  36 |   100/ 1844 batches | lr 2.00 | ms/batch 8.245 | loss  1.59 | ppl     4.92
# | epoch  36 |   200/ 1844 batches | lr 2.00 | ms/batch 8.126 | loss  1.47 | ppl     4.34
# | epoch  36 |   300/ 1844 batches | lr 2.00 | ms/batch 8.129 | loss  1.44 | ppl     4.22
# | epoch  36 |   400/ 1844 batches | lr 2.00 | ms/batch 8.170 | loss  1.50 | ppl     4.50
# | epoch  36 |   500/ 1844 batches | lr 2.00 | ms/batch 8.105 | loss  1.52 | ppl     4.57
# | epoch  36 |   600/ 1844 batches | lr 2.00 | ms/batch 8.186 | loss  1.52 | ppl     4.55
# | epoch  36 |   700/ 1844 batches | lr 2.00 | ms/batch 8.224 | loss  1.46 | ppl     4.29
# | epoch  36 |   800/ 1844 batches | lr 2.00 | ms/batch 8.075 | loss  1.43 | ppl     4.19
# | epoch  36 |   900/ 1844 batches | lr 2.00 | ms/batch 8.118 | loss  1.49 | ppl     4.45
# | epoch  36 |  1000/ 1844 batches | lr 2.00 | ms/batch 8
 1844 batches | lr 2.00 | ms/batch 8.119 | loss  1.46 | ppl     4.30
# | epoch  38 |   700/ 1844 batches | lr 2.00 | ms/batch 8.080 | loss  1.42 | ppl     4.14
# | epoch  38 |   800/ 1844 batches | lr 2.00 | ms/batch 8.164 | loss  1.35 | ppl     3.86
# | epoch  38 |   900/ 1844 batches | lr 2.00 | ms/batch 8.097 | loss  1.46 | ppl     4.32
# | epoch  38 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.212 | loss  1.43 | ppl     4.18
# | epoch  38 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.097 | loss  1.50 | ppl     4.49
# | epoch  38 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.123 | loss  1.44 | ppl     4.23
# | epoch  38 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.109 | loss  1.40 | ppl     4.07
# | epoch  38 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.140 | loss  1.43 | ppl     4.18
# | epoch  38 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.122 | loss  1.38 | ppl     3.99
# | epoch  38 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.113 | loss  1.47 | ppl     4.34
# | epoch  38 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.113 | loss  1.43 | ppl     4.19
# | epoch  38 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.119 | loss  1.42 | ppl     4.15
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 20.17s | valid loss 0.810 | valid ppl     2.25
# -----------------------------------------------------------------------------------------
# | epoch  39 |   100/ 1844 batches | lr 2.00 | ms/batch 8.280 | loss  1.51 | ppl     4.54
# | epoch  39 |   200/ 1844 batches | lr 2.00 | ms/batch 8.206 | loss  1.44 | ppl     4.24
# | epoch  39 |   300/ 1844 batches | lr 2.00 | ms/batch 8.081 | loss  1.36 | ppl     3.88
# | epoch  39 |   400/ 1844 batches | lr 2.00 | ms/batch 8.124 | loss  1.38 | ppl     3.99
# | epoch  39 |   500/ 1844 batches | lr 2.00 | ms/batch 8.138 | loss  1.45 | ppl     4.26
# | epoch  39 |   600/ 1844 batches | lr 2.00 | ms/batch 8.066 | loss  1.44 | ppl     4.24
# | epoch  39 |   700/ 1844 batches | lr 2.00 | ms/batch 8.123 | loss  1.41 | ppl     4.10
# | epoch  39 |   800/ 1844 batches | lr 2.00 | ms/batch 8.088 | loss  1.33 | ppl     3.77
# | epoch  39 |   900/ 1844 batches | lr 2.00 | ms/batch 8.112 | loss  1.41 | ppl     4.11
# | epoch  39 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.059 | loss  1.36 | ppl     3.89
# | epoch  39 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.207 | loss  1.44 | ppl     4.24
# | epoch  39 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.094 | loss  1.38 | ppl     3.99
# | epoch  39 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.071 | loss  1.39 | ppl     4.03
# | epoch  39 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.139 | loss  1.44 | ppl     4.23
# | epoch  39 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.203 | loss  1.35 | ppl     3.87
# | epoch  39 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.139 | loss  1.43 | ppl     4.17
# | epoch  39 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.093 | loss  1.35 | ppl     3.87
# | epoch  39 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.152 | loss  1.45 | ppl     4.26
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 20.19s | valid loss 0.821 | valid ppl     2.27
# -----------------------------------------------------------------------------------------
# | epoch  40 |   100/ 1844 batches | lr 2.00 | ms/batch 8.286 | loss  1.47 | ppl     4.35
# | epoch  40 |   200/ 1844 batches | lr 2.00 | ms/batch 8.158 | loss  1.40 | ppl     4.05
# | epoch  40 |   300/ 1844 batches | lr 2.00 | ms/batch 8.123 | loss  1.34 | ppl     3.81
# | epoch  40 |   400/ 1844 batches | lr 2.00 | ms/batch 8.227 | loss  1.33 | ppl     3.77
# | epoch  40 |   500/ 1844 batches | lr 2.00 | ms/batch 8.095 | loss  1.42 | ppl     4.14
# | epoch  40 |   600/ 1844 batches | lr 2.00 | ms/batch 8.227 | loss  1.42 | ppl     4.15
# | epoch  40 |   700/ 1844 batches | lr 2.00 | ms/batch 8.130 | loss  1.34 | ppl     3.83
# | epoch  40 |   800/ 1844 batches | lr 2.00 | ms/batch 8.160 | loss  1.29 | ppl     3.63
# | epoch  40 |   900/ 1844 batches | lr 2.00 | ms/batch 8.268 | loss  1.41 | ppl     4.08
# | epoch  40 |  1000/ 1844 batches | lr 2.00 | ms/batch 8.152 | loss  1.35 | ppl     3.85
# | epoch  40 |  1100/ 1844 batches | lr 2.00 | ms/batch 8.139 | loss  1.40 | ppl     4.07
# | epoch  40 |  1200/ 1844 batches | lr 2.00 | ms/batch 8.098 | loss  1.37 | ppl     3.92
# | epoch  40 |  1300/ 1844 batches | lr 2.00 | ms/batch 8.169 | loss  1.31 | ppl     3.70
# | epoch  40 |  1400/ 1844 batches | lr 2.00 | ms/batch 8.152 | loss  1.38 | ppl     3.96
# | epoch  40 |  1500/ 1844 batches | lr 2.00 | ms/batch 8.054 | loss  1.35 | ppl     3.85
# | epoch  40 |  1600/ 1844 batches | lr 2.00 | ms/batch 8.100 | loss  1.41 | ppl     4.11
# | epoch  40 |  1700/ 1844 batches | lr 2.00 | ms/batch 8.127 | loss  1.34 | ppl     3.82
# | epoch  40 |  1800/ 1844 batches | lr 2.00 | ms/batch 8.143 | loss  1.41 | ppl     4.12
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 20.19s | valid loss 0.799 | valid ppl     2.22
# -----------------------------------------------------------------------------------------

# %% [markdown]
# ### Проверка качества, экспорт в ONNX

# %%
# Загрузка лучшей модели.
with open(savefile, 'rb') as f:
    model = torch.load(f)
    # после загрузки параметры RNN находятся не в одном сегменте памяти
    # для помещения в один участок и ускорения прямого прохода
    # В настоящее время, только рекуррентная модель поддерживает flatten_parameters.
    if model_type in ['RNN_TANH', 'RNN_RELU', 'LSTM', 'GRU']:
        model.rnn.flatten_parameters()

# Финальная проверка качества
test_loss = evaluate(y)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.3f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)

onnx_export = '%s_next_token.onnx'%(model_type)
if len(onnx_export) > 0:
    # Экспортирование модели в формат ONNX
    export_onnx(onnx_export, batch_size=1, seq_len=WINDOW_SIZE)
# Out:
# =========================================================================================
# | End of training | test loss  0.80 | test ppl    2.224
# =========================================================================================
# The model is also exported in ONNX format at /content/Transformer_next_token.onnx.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:179: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:179: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:180: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.

# %% [markdown]
# ### Получение эмбеддингов, проекция в 2D

# %%
#from sklearn.decomposition import PCA
embeddings = list(model.encoder.parameters())[0].detach().cpu().numpy()

embeddings = UMAP(n_components=2, random_state=2).fit_transform(embeddings)

# %% [markdown]
# ### Визуализация пространства эмбеддингов

# %%
# Визуализация обученных эмбеддингов
fig, ax = plt.subplots(figsize=(20, 20))
ax.scatter(embeddings[:, 0], embeddings[:, 1], s=0.5, alpha=0.4)

# берём 300 наиболее частых
whitelist = frozenset(corpus_df.token_ids.value_counts().index[:300].values)
for i, txt in enumerate(embeddings):
    token_id = ids2token_ids[i]
    if token_id not in whitelist:
        continue
    ax.annotate(vocabs[token_id][0],
                (embeddings[i][0], embeddings[i][1]))
plt.savefig('vecs_%s.svg'%model_type)
